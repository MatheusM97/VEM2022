# %%
#pip install PyGithub

# %%
from datetime import datetime
import os
import pandas as pd
os.getcwd()
import pandas as pd
import sys
import numpy

# %%
google = pd.read_csv("../1-ExtractDataPRs/Data2022/googlesamples2022.csv")
aws = pd.read_csv("../1-ExtractDataPRs/Data2022/aws2022.csv")
azure = pd.read_csv("../1-ExtractDataPRs/Data2022/azure2022.csv")
spring = pd.read_csv("../1-ExtractDataPRs/Data2022/spring-guides2022.csv")

# %%
#print(len(aws[(aws['merged'] == True) ]['merge user login'].dropna().unique()))
#print(len(google[(google['merged'] == True)]['merge user login'].dropna().unique()))
#print(len(azure[(azure['merged'] == True)]['merge user login'].dropna().unique()))
#print(len(spring[(spring['merged'] == True)]['merge user login'].dropna().unique()))

#print("")

#print(aws[(aws['merged'] == True)]['merge user login'].nunique())
#print(google[(google['merged'] == True)]['merge user login'].nunique())
#print(azure[(azure['merged'] == True)]['merge user login'].nunique())
#print(spring[(spring['merged'] == True)]['merge user login'].nunique())

#Getting maintainer(collaborators internals)
aws_logins = aws[(aws['merged'] == True) ]['merge user login'].dropna().unique()
google_logins = google[(google['merged'] == True)]['merge user login'].dropna().unique()
azure_logins =  azure[(azure['merged'] == True)]['merge user login'].dropna().unique()
spring_logins = spring[(spring['merged'] == True)]['merge user login'].dropna().unique()
print(aws_logins)
# Out:
# ['jweiss' 'jeremeamia' 'NoSQLKnowHow' ... 'wangz10' 'jeromeb'
#  'gunnargrosch']

# %%
def remove_internal_pull_requests(pulls, maintainers):
  #unique_maintainers = maintainers["login"].unique()
  #print(len(maintainers))  
  #print(maintainers)  
  last_index = pulls.index[-1]
  for index in pulls.index:
   # print(index, last_index)
    line = pulls.loc[index]
    creator = line["creator user login"]
    if creator in maintainers:
      pulls.drop(index, inplace=True)

# %%
aws
# Out:
#          framework                                             sample  \
# 0      aws-samples             aws-samples/opsworks-example-cookbooks
# 1      aws-samples             aws-samples/opsworks-example-cookbooks
# 2      aws-samples             aws-samples/opsworks-example-cookbooks
# 3      aws-samples             aws-samples/opsworks-example-cookbooks
# 4      aws-samples             aws-samples/opsworks-example-cookbooks
# ...            ...                                                ...
# 34025  aws-samples       aws-samples/aws-account-provisioning-api-sls
# 34026  aws-samples  aws-samples/aws-vpc-provisioning-api-samcli-do...
# 34027  aws-samples     aws-samples/amz-vpc-provision-connectivity-sls
# 34028  aws-samples       aws-samples/amazon-ec2-cloudwatch-alarms-sls
# 34029  aws-samples         aws-samples/cdk-hyperledger-fabric-network
#
#                                                     link      data de criação  \
# 0      https://github.com/aws-samples/opsworks-exampl...  2019-10-21 14:09:08
# 1      https://github.com/aws-samples/opsworks-exampl...  2019-02-27 11:30:52
# 2      https://github.com/aws-samples/opsworks-exampl...  2017-10-10 12:13:52
# 3      https://github.com/aws-samples/opsworks-exampl...  2017-05-12 09:53:05
# 4      https://github.com/aws-samples/opsworks-exampl...  2016-03-22 12:43:30
# ...                                                  ...                  ...
# 34025  https://github.com/aws-samples/aws-account-pro...  2021-12-21 17:27:29
# 34026  https://github.com/aws-samples/aws-vpc-provisi...  2021-12-21 16:57:14
# 34027  https://github.com/aws-samples/amz-vpc-provisi...  2021-12-22 09:48:44
# 34028  https://github.com/aws-samples/amazon-ec2-clou...  2021-12-24 14:34:30
# 34029  https://github.com/aws-samples/cdk-hyperledger...  2022-01-05 00:03:46
#
#         data de fechamento  tempo para fechamento  tempo merge  \
# 0                      NaN                    NaN          NaN
# 1                      NaN                    NaN          NaN
# 2                      NaN                    NaN          NaN
# 3      2017-05-12 13:56:55                    0.0          0.0
# 4      2016-05-14 09:59:33                   52.0          NaN
# ...                    ...                    ...          ...
# 34025  2021-12-21 17:27:40                    0.0          0.0
# 34026  2021-12-21 16:57:28                    0.0          0.0
# 34027  2021-12-22 09:48:55                    0.0          0.0
# 34028  2021-12-24 14:34:43                    0.0          0.0
# 34029  2022-01-05 03:56:45                    0.0          NaN
#
#                 data merge  data de atualização  merged  ...  \
# 0                      NaN  2019-10-21 14:09:08   False  ...
# 1                      NaN  2019-02-27 11:30:52   False  ...
# 2                      NaN  2017-10-10 12:13:52   False  ...
# 3      2017-05-12 13:56:55  2017-05-12 13:56:55    True  ...
# 4                      NaN  2016-05-14 09:59:33   False  ...
# ...                    ...                  ...     ...  ...
# 34025  2021-12-21 17:27:40  2021-12-21 17:27:40    True  ...
# 34026  2021-12-21 16:57:28  2021-12-21 16:57:28    True  ...
# 34027  2021-12-22 09:48:55  2021-12-22 09:48:55    True  ...
# 34028  2021-12-24 14:34:43  2021-12-24 14:34:44    True  ...
# 34029                  NaN  2022-01-05 04:37:52   False  ...
#
#            closed user email closed user seguidores  total de reviews  \
# 0                        NaN                    NaN               0.0
# 1                        NaN                    NaN               0.0
# 2                        NaN                    NaN               0.0
# 3            jw@innerewut.de                  169.0               0.0
# 4                        NaN                    0.0               0.0
# ...                      ...                    ...               ...
# 34025                    NaN                    NaN               NaN
# 34026                    NaN                    0.0               0.0
# 34027                    NaN                    NaN               NaN
# 34028                    NaN                    0.0               0.0
# 34029  judson.neer@gmail.com                   17.0               0.0
#
#       revisores login review approved user cargo review approved user empresa  \
# 0                 NaN                        NaN                          NaN
# 1                 NaN                        NaN                          NaN
# 2                 NaN                        NaN                          NaN
# 3                 NaN                        NaN                          NaN
# 4                 NaN                        NaN                          NaN
# ...               ...                        ...                          ...
# 34025             NaN                        NaN                          NaN
# 34026             NaN                        NaN                          NaN
# 34027             NaN                        NaN                          NaN
# 34028             NaN                        NaN                          NaN
# 34029             NaN                        NaN                          NaN
#
#       review approved user local  review approved user login  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 34025                        NaN                         NaN
# 34026                        NaN                         NaN
# 34027                        NaN                         NaN
# 34028                        NaN                         NaN
# 34029                        NaN                         NaN
#
#        review approved user email  review approved user seguidores
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# ...                           ...                              ...
# 34025                         NaN                              NaN
# 34026                         NaN                              NaN
# 34027                         NaN                              NaN
# 34028                         NaN                              NaN
# 34029                         NaN                              NaN
#
# [34030 rows x 40 columns]

# %%
google
# Out:
#          framework                          sample  \
# 0    googlesamples  googlesamples/web-fundamentals
# 1    googlesamples  googlesamples/web-fundamentals
# 2    googlesamples  googlesamples/web-fundamentals
# 3    googlesamples  googlesamples/web-fundamentals
# 4    googlesamples  googlesamples/web-fundamentals
# ..             ...                             ...
# 829  googlesamples      googlesamples/task-interop
# 830  googlesamples      googlesamples/task-interop
# 831  googlesamples      googlesamples/task-interop
# 832  googlesamples      googlesamples/task-interop
# 833  googlesamples      googlesamples/task-interop
#
#                                                   link      data de criação  \
# 0    https://github.com/googlesamples/web-fundament...  2019-07-08 20:15:51
# 1    https://github.com/googlesamples/web-fundament...  2019-07-08 16:39:22
# 2    https://github.com/googlesamples/web-fundament...  2019-03-04 23:26:32
# 3    https://github.com/googlesamples/web-fundament...  2018-11-15 21:57:25
# 4    https://github.com/googlesamples/web-fundament...  2017-05-31 17:55:16
# ..                                                 ...                  ...
# 829  https://github.com/googlesamples/task-interop/...  2020-11-24 17:04:13
# 830  https://github.com/googlesamples/task-interop/...  2020-11-20 17:11:38
# 831  https://github.com/googlesamples/task-interop/...  2020-11-18 21:38:00
# 832  https://github.com/googlesamples/task-interop/...  2020-11-18 20:00:25
# 833  https://github.com/googlesamples/task-interop/...  2020-11-18 17:25:57
#
#       data de fechamento  tempo para fechamento  tempo merge  \
# 0    2020-08-14 11:30:29                  402.0          NaN
# 1    2019-07-08 17:52:29                    0.0          NaN
# 2    2019-03-04 23:29:17                    0.0          0.0
# 3                    NaN                    NaN          NaN
# 4                    NaN                    NaN          NaN
# ..                   ...                    ...          ...
# 829  2020-11-24 19:08:46                    0.0          0.0
# 830  2020-11-20 20:53:45                    0.0          0.0
# 831  2020-11-20 17:22:24                    1.0          NaN
# 832  2020-11-18 21:34:32                    0.0          NaN
# 833  2020-11-19 21:57:29                    1.0          1.0
#
#               data merge  data de atualização  merged  ... closed user email  \
# 0                    NaN  2020-08-14 11:30:29   False  ...               NaN
# 1                    NaN  2019-07-09 12:01:28   False  ...               NaN
# 2    2019-03-04 23:29:17  2019-03-04 23:29:50    True  ...               NaN
# 3                    NaN  2018-11-16 01:01:57   False  ...               NaN
# 4                    NaN  2017-05-31 17:59:26   False  ...               NaN
# ..                   ...                  ...     ...  ...               ...
# 829  2020-11-24 19:08:45  2020-11-24 19:09:18    True  ...               NaN
# 830  2020-11-20 20:53:45  2020-11-24 19:09:47    True  ...               NaN
# 831                  NaN  2020-11-20 17:22:31   False  ...               NaN
# 832                  NaN  2020-11-18 21:34:41   False  ...               NaN
# 833  2020-11-19 21:57:29  2020-11-19 21:57:29    True  ...               NaN
#
#     closed user seguidores  total de reviews  revisores login  \
# 0                      1.0               1.0       johyphenel
# 1                      1.0               0.0              NaN
# 2                   4222.0               1.0     philipwalton
# 3                      NaN               0.0              NaN
# 4                      NaN               0.0              NaN
# ..                     ...               ...              ...
# 829                    3.0               1.0        Google-JM
# 830                    3.0               1.0        Google-JM
# 831                    3.0               0.0              NaN
# 832                    3.0               0.0              NaN
# 833                    3.0               2.0  caller9 caller9
#
#     review approved user cargo review approved user empresa  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                       Google
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 829                        NaN                          NaN
# 830                        NaN                          NaN
# 831                        NaN                          NaN
# 832                        NaN                          NaN
# 833                        NaN                          NaN
#
#     review approved user local  review approved user login  \
# 0                          NaN                  johyphenel
# 1                          NaN                         NaN
# 2              Los Angeles, CA                philipwalton
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 829                        NaN                   Google-JM
# 830                        NaN                   Google-JM
# 831                        NaN                         NaN
# 832                        NaN                         NaN
# 833                      Texas                     caller9
#
#      review approved user email  review approved user seguidores
# 0                           NaN                              4.0
# 1                           NaN                              NaN
# 2                           NaN                           4222.0
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# ..                          ...                              ...
# 829                         NaN                              0.0
# 830                         NaN                              0.0
# 831                         NaN                              NaN
# 832                         NaN                              NaN
# 833                         NaN                              3.0
#
# [834 rows x 40 columns]

# %%
remove_internal_pull_requests(google, google_logins)
remove_internal_pull_requests(spring, spring_logins)
remove_internal_pull_requests(aws, aws_logins)
remove_internal_pull_requests(azure, azure_logins)

# %%
def remove_auto_closed(pulls):
  last_index = pulls.index[-1]
  for index in pulls.index:
   # print(index, last_index)
    line = pulls.loc[index]
    if (line["creator user login"] == line["closed user login"]):
      pulls.drop(index, inplace=True)

# %%
remove_auto_closed(google)
remove_auto_closed(spring)
remove_auto_closed(aws)
remove_auto_closed(azure)

# %%
print(len(google.index))
print(len(aws.index))
print(len(azure.index))
print(len(spring.index))
# Out:
# 483
# 6194
# 4933
# 1150

# %%
from numpy import NaN
def agregarColaboradores(framework_PRs,framework, logins):
  objetos = list()
  numero_prs_criados = 0
  numero_merges = 0
  numero_prs_criado_mergeado = 0
  numero_prs_criado_n_mergeado = 0
  numero_prs_nmergeado_fechado = 0
  numero_prs_fechado = 0 
  seguidores = 0

  data_inicial = 0
  data_final = 0
  valor_dias_experiencia = 0

  framework_PRs.columns = framework_PRs.columns.str.replace(' ', '_') 
  #logins = framework_PRs[(framework_PRs['merged'] == True)]['merge_user_login'].dropna().unique()
  print(len(logins))
  print(logins)
  for i in range(0,len(logins)):
    print(logins[i])
    #merged by maintainer independent contributor
    numero_merges = framework_PRs[(framework_PRs.merge_user_login == logins[i])]['merge_user_login'].count()
    #prs created by maintainer
    numero_prs_criados = framework_PRs[(framework_PRs.creator_user_login == logins[i])]['creator_user_login'].count()
    #creator and merged by maintainer
    numero_prs_criado_mergeado = framework_PRs[(framework_PRs.creator_user_login == logins[i]) & (framework_PRs.merge_user_login == logins[i])]['merge_user_login'].count()
    #created by maintainer but not merged and closed by someone
    numero_prs_criado_n_mergeado = framework_PRs[(framework_PRs.creator_user_login == logins[i]) & (framework_PRs.merged == False) & (framework_PRs.status == 'closed')]['creator_user_login'].count()
    #created by anyone, not merged and closed by the maintainer in question
    numero_prs_nmergeado_fechado = framework_PRs[(framework_PRs.closed_user_login == logins[i]) & (framework_PRs.merged == False)  & (framework_PRs.status == 'closed')]['closed_user_login'].count()
    #created by anyone, independent of merged and closed by the maintainer
    numero_prs_fechado = framework_PRs[(framework_PRs.closed_user_login == logins[i])  & (framework_PRs.status == 'closed')]['closed_user_login'].count()
    #created by anyone(not maintainer) and merged
    numero_merges_exclude_auto_merge = framework_PRs[(framework_PRs.merge_user_login == logins[i]) & (framework_PRs.creator_user_login != logins[i])]['merge_user_login'].count()
    #created by anyone(not maintainer) and just closed (reviewed accepted or not)
    numero_revisoes_exclude_auto_revisado = framework_PRs[(framework_PRs.closed_user_login == logins[i])  & (framework_PRs.status == 'closed') & (framework_PRs.creator_user_login != logins[i])]['closed_user_login'].count()
    #auto_review
    auto_revisado = framework_PRs[(framework_PRs.closed_user_login == logins[i])  & (framework_PRs.status == 'closed') & (framework_PRs.creator_user_login == logins[i])]['closed_user_login'].count()
    
    #print(numero_prs_nmergeado_fechado)
    #print(numero_merges)
    #if exists closed, but don't merged
    if(numero_merges > 0 or numero_prs_nmergeado_fechado > 0):
      seguidores = framework_PRs[(framework_PRs.closed_user_login == logins[i])]['closed_user_seguidores'].dropna().sort_values()
      #print(seguidores)
      if(len(seguidores) > 0):
        seguidores = seguidores.iloc[-1]

      #print("seguidores " + str(seguidores))
      datas = framework_PRs[(framework_PRs.merge_user_login == logins[i])]['data_merge'].dropna().sort_values()
      datas_closed = framework_PRs[(framework_PRs.closed_user_login == logins[i]) ]['data_de_fechamento'].dropna().sort_values()
      #print(datas)
      #print(datas_closed)
        
      if(numero_merges_exclude_auto_merge > 0):
        if datas.iloc[0] > datas_closed.iloc[0]:
          data_inicial = datas_closed.iloc[0]
        else:
          data_inicial =  datas.iloc[0]

        #print(data_inicial)  

        if datas.iloc[-1] < datas_closed.iloc[-1]:
          data_final = datas_closed.iloc[-1]
        else:
          data_final =  datas.iloc[-1]
        #print( data_final) 
  
    
        valor_dias_experiencia =  (datetime.strptime(data_final, '%Y-%m-%d %H:%M:%S') - datetime.strptime(data_inicial, '%Y-%m-%d %H:%M:%S')).days
        #print(valor_dias_experiencia)
    else:
      seguidores = ''
      datas = framework_PRs[(framework_PRs.merge_user_login == logins[i])]['data_merge'].dropna().sort_values()
      datas_closed = framework_PRs[(framework_PRs.closed_user_login == logins[i]) ]['data_de_fechamento'].dropna().sort_values()
    
    
    #print(datas)
    #print(datas_closed)
    #print(numero_prs_criados)
    #print(numero_merges)
    #print(numero_prs_criado_mergeado)
    #print(numero_prs_criado_n_mergeado)
    #print(numero_prs_nmergeado_fechado)
    #print(numero_prs_fechado)
    #print(numero_merges_exclude_auto_merge)

    

    objeto = {
        "framework": framework,
        "login": logins[i], 
        "seguidores": seguidores,
        "numero_prs_criados":  numero_prs_criados,
        "numero_merges":  numero_merges,
        "numero_prs_criado_mergeado": numero_prs_criado_mergeado,
        "numero_prs_criado_n_mergeado": numero_prs_criado_n_mergeado,
        "numero_prs_n_mergeado_fechado": numero_prs_nmergeado_fechado,
        "numero_prs_fechado": numero_prs_fechado,
        "numero_merges_exclude_auto_merge" : numero_merges_exclude_auto_merge,
        "numero_revisoes_exclude_auto_revisado": numero_revisoes_exclude_auto_revisado,
        "auto_revisado" : auto_revisado,
        "tempo experiencia(dias)": valor_dias_experiencia
    }
    objetos.append(objeto)

  df = pd.DataFrame(objetos)
  return df

# %%
aws
# Out:
#          framework                                             sample  \
# 0      aws-samples             aws-samples/opsworks-example-cookbooks
# 1      aws-samples             aws-samples/opsworks-example-cookbooks
# 2      aws-samples             aws-samples/opsworks-example-cookbooks
# 3      aws-samples             aws-samples/opsworks-example-cookbooks
# 5      aws-samples             aws-samples/opsworks-example-cookbooks
# ...            ...                                                ...
# 34014  aws-samples  aws-samples/kubernetes-log4j-cve-2021-44228-no...
# 34018  aws-samples                 aws-samples/serverless-kotlin-demo
# 34019  aws-samples                 aws-samples/serverless-kotlin-demo
# 34020  aws-samples                 aws-samples/serverless-kotlin-demo
# 34021  aws-samples  aws-samples/aws-healthcare-lifescience-ai-ml-s...
#
#                                                     link      data de criação  \
# 0      https://github.com/aws-samples/opsworks-exampl...  2019-10-21 14:09:08
# 1      https://github.com/aws-samples/opsworks-exampl...  2019-02-27 11:30:52
# 2      https://github.com/aws-samples/opsworks-exampl...  2017-10-10 12:13:52
# 3      https://github.com/aws-samples/opsworks-exampl...  2017-05-12 09:53:05
# 5      https://github.com/aws-samples/opsworks-exampl...  2014-11-07 18:00:27
# ...                                                  ...                  ...
# 34014  https://github.com/aws-samples/kubernetes-log4...  2021-12-16 16:56:40
# 34018  https://github.com/aws-samples/serverless-kotl...  2021-12-28 08:29:19
# 34019  https://github.com/aws-samples/serverless-kotl...  2021-12-21 19:38:01
# 34020  https://github.com/aws-samples/serverless-kotl...  2021-12-17 19:33:42
# 34021  https://github.com/aws-samples/aws-healthcare-...  2022-01-08 01:54:50
#
#         data de fechamento  tempo para fechamento  tempo merge  \
# 0                      NaN                    NaN          NaN
# 1                      NaN                    NaN          NaN
# 2                      NaN                    NaN          NaN
# 3      2017-05-12 13:56:55                    0.0          0.0
# 5                      NaN                    NaN          NaN
# ...                    ...                    ...          ...
# 34014  2021-12-16 17:03:34                    0.0          0.0
# 34018  2022-01-04 10:21:39                    7.0          7.0
# 34019  2021-12-21 21:29:06                    0.0          0.0
# 34020  2021-12-18 20:05:46                    1.0          1.0
# 34021                  NaN                    NaN          NaN
#
#                 data merge  data de atualização  merged  ...  \
# 0                      NaN  2019-10-21 14:09:08   False  ...
# 1                      NaN  2019-02-27 11:30:52   False  ...
# 2                      NaN  2017-10-10 12:13:52   False  ...
# 3      2017-05-12 13:56:55  2017-05-12 13:56:55    True  ...
# 5                      NaN  2014-11-07 18:00:27   False  ...
# ...                    ...                  ...     ...  ...
# 34014  2021-12-16 17:03:34  2021-12-16 17:14:55    True  ...
# 34018  2022-01-04 10:21:39  2022-01-04 10:21:39    True  ...
# 34019  2021-12-21 21:29:06  2021-12-21 22:58:12    True  ...
# 34020  2021-12-18 20:05:46  2021-12-18 21:23:32    True  ...
# 34021                  NaN  2022-01-08 01:54:50   False  ...
#
#             closed user email closed user seguidores  total de reviews  \
# 0                         NaN                    NaN               0.0
# 1                         NaN                    NaN               0.0
# 2                         NaN                    NaN               0.0
# 3             jw@innerewut.de                  169.0               0.0
# 5                         NaN                    NaN               0.0
# ...                       ...                    ...               ...
# 34014                     NaN                   49.0               0.0
# 34018                     NaN                   26.0               0.0
# 34019                     NaN                   26.0               1.0
# 34020                     NaN                   26.0               1.0
# 34021  joshuabroyde@gmail.com                    2.0               0.0
#
#       revisores login review approved user cargo review approved user empresa  \
# 0                 NaN                        NaN                          NaN
# 1                 NaN                        NaN                          NaN
# 2                 NaN                        NaN                          NaN
# 3                 NaN                        NaN                          NaN
# 5                 NaN                        NaN                          NaN
# ...               ...                        ...                          ...
# 34014             NaN                        NaN                          NaN
# 34018             NaN                        NaN                          NaN
# 34019      marksailes                        NaN                          NaN
# 34020         msailes                        NaN          Amazon Web Services
# 34021             NaN                        NaN                          NaN
#
#       review approved user local  review approved user login  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 5                            NaN                         NaN
# ...                          ...                         ...
# 34014                        NaN                         NaN
# 34018                        NaN                         NaN
# 34019                  Leeds, UK                  marksailes
# 34020                  Leeds, UK                     msailes
# 34021                        NaN                         NaN
#
#        review approved user email  review approved user seguidores
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 5                             NaN                              NaN
# ...                           ...                              ...
# 34014                         NaN                              NaN
# 34018                         NaN                              NaN
# 34019                         NaN                              8.0
# 34020                         NaN                             26.0
# 34021                         NaN                              NaN
#
# [6194 rows x 40 columns]

# %%
google
# Out:
#          framework                          sample  \
# 2    googlesamples  googlesamples/web-fundamentals
# 3    googlesamples  googlesamples/web-fundamentals
# 4    googlesamples  googlesamples/web-fundamentals
# 5    googlesamples  googlesamples/web-fundamentals
# 8    googlesamples  googlesamples/web-fundamentals
# ..             ...                             ...
# 811  googlesamples             googlesamples/mlkit
# 816  googlesamples             googlesamples/mlkit
# 823  googlesamples             googlesamples/mlkit
# 827  googlesamples  googlesamples/arcore-depth-lab
# 833  googlesamples      googlesamples/task-interop
#
#                                                   link      data de criação  \
# 2    https://github.com/googlesamples/web-fundament...  2019-03-04 23:26:32
# 3    https://github.com/googlesamples/web-fundament...  2018-11-15 21:57:25
# 4    https://github.com/googlesamples/web-fundament...  2017-05-31 17:55:16
# 5    https://github.com/googlesamples/web-fundament...  2017-04-10 19:51:26
# 8    https://github.com/googlesamples/web-fundament...  2016-04-15 09:19:04
# ..                                                 ...                  ...
# 811     https://github.com/googlesamples/mlkit/pull/63  2020-07-01 20:58:47
# 816     https://github.com/googlesamples/mlkit/pull/21  2020-06-19 16:11:45
# 823      https://github.com/googlesamples/mlkit/pull/7  2020-06-05 18:01:50
# 827  https://github.com/googlesamples/arcore-depth-...  2021-06-27 05:33:24
# 833  https://github.com/googlesamples/task-interop/...  2020-11-18 17:25:57
#
#       data de fechamento  tempo para fechamento  tempo merge  \
# 2    2019-03-04 23:29:17                    0.0          0.0
# 3                    NaN                    NaN          NaN
# 4                    NaN                    NaN          NaN
# 5    2017-04-10 20:10:09                    0.0          0.0
# 8                    NaN                    NaN          NaN
# ..                   ...                    ...          ...
# 811  2020-07-01 21:05:50                    0.0          0.0
# 816  2020-06-19 17:26:47                    0.0          0.0
# 823  2020-08-22 04:00:49                   77.0          NaN
# 827  2021-08-22 23:50:25                   56.0         56.0
# 833  2020-11-19 21:57:29                    1.0          1.0
#
#               data merge  data de atualização  merged  ...  \
# 2    2019-03-04 23:29:17  2019-03-04 23:29:50    True  ...
# 3                    NaN  2018-11-16 01:01:57   False  ...
# 4                    NaN  2017-05-31 17:59:26   False  ...
# 5    2017-04-10 20:10:09  2017-04-10 20:10:24    True  ...
# 8                    NaN  2017-07-02 21:35:57   False  ...
# ..                   ...                  ...     ...  ...
# 811  2020-07-01 21:05:50  2020-07-05 15:42:38    True  ...
# 816  2020-06-19 17:26:47  2020-06-19 17:26:48    True  ...
# 823                  NaN  2020-08-22 04:00:50   False  ...
# 827  2021-08-22 23:50:25  2021-08-22 23:50:26    True  ...
# 833  2020-11-19 21:57:29  2020-11-19 21:57:29    True  ...
#
#             closed user email closed user seguidores  total de reviews  \
# 2                         NaN                 4222.0               1.0
# 3                         NaN                    NaN               0.0
# 4                         NaN                    NaN               0.0
# 5    meggin.kearney@gmail.com                  109.0               0.0
# 8                         NaN                    NaN               2.0
# ..                        ...                    ...               ...
# 811                       NaN                  216.0               1.0
# 816                       NaN                  216.0               1.0
# 823      zhouyiself@gmail.com                   12.0               0.0
# 827                       NaN                  166.0               0.0
# 833                       NaN                    3.0               2.0
#
#            revisores login review approved user cargo  \
# 2             philipwalton                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 8    johyphenel johyphenel                        NaN
# ..                     ...                        ...
# 811                 calren                        NaN
# 816                 calren                        NaN
# 823                    NaN                        NaN
# 827                    NaN                        NaN
# 833        caller9 caller9                        NaN
#
#     review approved user empresa review approved user local  \
# 2                         Google            Los Angeles, CA
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# 5                            NaN                        NaN
# 8                            NaN                        NaN
# ..                           ...                        ...
# 811                       Google              San Francisco
# 816                       Google              San Francisco
# 823                          NaN                        NaN
# 827                          NaN                        NaN
# 833                          NaN                      Texas
#
#      review approved user login  review approved user email  \
# 2                  philipwalton                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# 8                           NaN                         NaN
# ..                          ...                         ...
# 811                      calren                         NaN
# 816                      calren                         NaN
# 823                         NaN                         NaN
# 827                         NaN                         NaN
# 833                     caller9                         NaN
#
#      review approved user seguidores
# 2                             4222.0
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 8                                NaN
# ..                               ...
# 811                            216.0
# 816                            216.0
# 823                              NaN
# 827                              NaN
# 833                              3.0
#
# [483 rows x 40 columns]

# %%
#dataframe = pd.DataFrame(columns=["framework", "login", "seguidores", "numero merges", "numero PRs criados", "tempo de atividades realizada(FL)"])


df_google =  agregarColaboradores(google,"Android", google_logins)
df_aws = agregarColaboradores(aws,"AWS",aws_logins)
df_azure = agregarColaboradores(azure,"Azure",azure_logins)
df_spring = agregarColaboradores(spring,"Spring",spring_logins)
# Out:
# 67
# ['philipwalton' 'Meggin' 'PaulKinlan' 'tjohns' 'PaulRashidi' 'nlativy'
#  'JoseAlcerreca' 'mcduan' 'jin-liu' 'cslink' 'dereksalama' 'jdgreenberg'
#  'ch40w31' 'tiembo' 'slinzner' 'campoy' 'samthor' 'hostirosti' 'mco-gh'
#  'caller9' 'samtstern' 'ulukaya' 'ianbarber' 'kroikie' 'silvolu' 'gguuss'
#  'jscott1989' 'tony-mak' 'liuyl' 'theoreticalb' 'pchx' 'claywilkinson'
#  'tnorbye' 'nageshs' 'grant' 'leedenison' 'chkuang-g' 'vimanyu'
#  'stewartmiles' 'johnb003' 'ggfan' 'hak' 'pspencil' 'juliantoledo'
#  'proppy' 'WilliamDenniss' 'bretmcg' 'DougSig' 'jfschmakeit' 'Fleker'
#  'WilliamHester' 'romanofranz' 'nic0lette' 'Leo-Neat' 'SigmanZero'
#  'tikurahul' 'kai-dream' 'brdaugherty' 'idzkowski-google' 'jbolinger'
#  'kpierzchalski' 'cs-googler' 'zhouyiself' 'swiyu' 'calren' 'sheepmaster'
#  'ruofeidu']
# philipwalton
# Meggin
# PaulKinlan
# tjohns
# PaulRashidi
# nlativy
# JoseAlcerreca
# mcduan
# jin-liu
# cslink
# dereksalama
# jdgreenberg
# ch40w31
# tiembo
# slinzner
# campoy
# samthor
# hostirosti
# mco-gh
# caller9
# samtstern
# ulukaya
# ianbarber
# kroikie
# silvolu
# gguuss
# jscott1989
# tony-mak
# liuyl
# theoreticalb
# pchx
# claywilkinson
# tnorbye
# nageshs
# grant
# leedenison
# chkuang-g
# vimanyu
# stewartmiles
# johnb003
# ggfan
# hak
# pspencil
# juliantoledo
# proppy
# WilliamDenniss
# bretmcg
# DougSig
# jfschmakeit
# Fleker
# WilliamHester
# romanofranz
# nic0lette
# Leo-Neat
# SigmanZero
# tikurahul
# kai-dream
# brdaugherty
# idzkowski-google
# jbolinger
# kpierzchalski
# cs-googler
# zhouyiself
# swiyu
# calren
# sheepmaster
# ruofeidu
# 1248
# ['jweiss' 'jeremeamia' 'NoSQLKnowHow' ... 'wangz10' 'jeromeb'
#  'gunnargrosch']
# jweiss
# jeremeamia
# NoSQLKnowHow
# amcp
# abhiksingh
# erichays
# petermoon
# zhangzhx
# hvivani
# mombergm
# stmcpherson
# christopherbozeman
# adamthom
# cliuamzn
# garrettjaeger
# Sekhar-Kutikuppala
# brettf
# mig281
# EronHennessey
# pmohan6
# jonathanq
# philstrong
# Helen1987
# yubangxi
# feverLu
# asaf-erlich
# ambareesha
# Jmcfar
# suryanarayanan
# jpignata
# kvasukib
# rohandubal
# karthiksaligrama
# dstroppa
# nathanpeck
# leopd
# BigLep
# chriszheng10
# zarandioon
# romerocesar
# keerthy411
# MarkAtwood
# pfifer
# mwunderl
# glez-aws
# nikhil-dabhade
# ahawker
# appwiz
# scottgoldwater
# bradley-curran
# sapessi
# hyandell
# srisub-amzn
# rjvgupta
# IanMeyers
# zach-data
# jbraeuer
# georgmao
# gthuang
# aaronkao
# teknogeek0
# melwin
# waleoladehin
# awood45
# dgomesbr
# mikeapted
# samdengler
# bdoncaster
# jbnunn
# jasdel
# julienlepine
# baldwinmatt
# imperalix
# kyleknap
# jamesls
# zoltak
# sunilmallya
# emcfins
# seajoshc
# katem7368
# jicowan
# PaulMaddox
# emurray1000
# kyarosh
# diegonat
# asifamz
# bls20AWS
# rts-rob
# angelarw
# mikedeck
# justonian
# Doug-AWS
# heitorlessa
# schallis
# atomicaws
# schmutze
# rajput-jitendra
# olivierklein
# willarmiros
# lupengamzn
# yogiraj07
# yishengl
# rabowskyb
# itzhapaz
# stilvoid
# mperi
# rnzsgh
# john
# isbkch
# jkahn117
# trenton
# taneemtee
# nhira
# awwerth
# smoell
# sthm
# smp
# lmbo-2020
# moomindani
# delagoya
# ajfriedman18
# dalbhanj
# anshrma
# awsed
# jpeddicord
# atoa
# bobpskier
# tomjames19
# JohnCalhoun
# darrylsosborne
# jamesiri
# jinspark-lab
# bskim
# ckassen
# buzzsurfr
# christopherhein
# arun-gupta
# scottmalkie
# brianhammons
# trevorrobertsjr
# nbrandaleone
# cubetoon
# koiker
# thebeebs
# marcilio
# chirillc-aws
# Nosajool
# TheRyanBurke
# palpatim
# undefobj
# mbtaws
# lyoungblood
# onlybakam
# adrianhall
# MikeDombo
# fengwang666
# K-AWS
# RBouaichiAWS
# seebees
# mattsb42-aws
# ksamreen
# thesnicketylemon
# lizroth
# arealjim
# praddc
# praus
# karlw00t
# abaird986
# morjoan
# JimTharioAmazon
# aburkleaux-amazon
# gmccarth
# awsmiev
# srinivasankrajeev
# fibbonnaci
# tescal2
# mike-starr
# alveko
# sunilchhablani
# p-palanis
# cgulliver
# omarlari
# sundarnarasiman
# ryanholland
# tomstickle
# ashika01
# clareliguori
# MCLDG
# pghedia
# meggers0
# jmfuchs
# araitats
# sammartinez
# iartemiev
# elorzafe
# galmeida
# jtrollin
# brianjbeach
# kwwaikar
# MitchyBAwesome
# buzzynz
# chapmancl
# jungji1
# brtrvn
# jdhardy
# davfaulk
# rdahlstrAWS
# iansrobinson
# beebs-systap
# bechbd
# ejazsyd
# sliedig
# mikejgillespie
# gowrishb
# kenstler
# aliasgarjh
# awsvik
# filanthropic
# jeffpuchalski
# rollucas
# rddefauw
# joshongithub
# steveataws
# svarvadekar
# lwilkovich
# da-miller
# JCoelhoo
# JeremyJohnsonAmazon
# DavidChristiansen
# dave-malone
# allenmichael
# hub714
# rudychetty
# muellerc
# kapadiazafar
# MixMasterMitch
# ranman
# eggoynes
# jarednielsen
# anuragrs
# haohanchen-yagao
# johnbensnyder
# rahul003
# yongwww
# adethyaa
# khanshariquem
# KasulaVamsi
# bryawood-aws
# malaval
# amrragab8080
# gmudambi
# hanzx227
# rday
# nalramli
# sggregoi
# kumarrk21
# rothgar
# brentley
# adamjkeller
# Jukie
# fmedery
# jlbutler
# oak2278
# paavan98pm
# vjsikha
# mschenli
# daekeun-ml
# pilhokim
# joe-norman
# yimuniao
# skvasant
# timmattison
# maheshda-aws
# marcosortiz
# janborch
# JoeJesse
# simonmarty
# kboxeth
# parimaldeshmukh
# madsid
# willtong1234
# wisemanIV
# robmarano
# jeffscottlevine
# edwinavalos
# ericzbeard
# ferdingler
# TheEmpty
# jfritche
# jonrhall
# github-actions[bot]
# peterwoodworth
# corymhall
# njlynch
# NGL321
# mergify[bot]
# ryparker
# eladb
# dependabot[bot]
# SomayaB
# rix0rrr
# MrArnoldPalmer
# RomainMuller
# garnaat
# pkohan
# alanmur
# chmarsaws
# dbinoy
# pputhran
# iarusv
# igalonso
# minbi
# Brettles
# skrinak
# MCLDG-zz
# twilson-aws
# nithu0115
# subfuzion
# awssandra
# tiffanyfay
# aughban
# steffeng
# dependabot-preview[bot]
# sirirako
# xiangshen-dk
# adam-aws
# rbboimer
# smohiuddin
# dabit3
# eddie1183
# sahikagenc
# wentzeld
# nealmcfee-aws
# muhyun
# james-jory
# chrisking
# luseloso
# sethiv
# dotgc
# muralibalki
# rsong6
# shimomut
# Yatrie
# christy
# ktonthat
# dcmaddix
# akhilrazdan
# lovvge
# yangcheng
# awsrossw
# matteofigus
# ctd
# HieronymusLex
# rezabekf
# schadem
# jt0
# EmilyWebber
# rrangnekar
# catcharbind
# ottokruse
# jxuamazon
# josiahbjorgaard
# yahavb
# ajayvohra2005
# tpbrogan
# naveenkoppula
# sagariiit
# mky4
# mgrzesiuk
# lameiro-amazon
# farleyb-amazon
# NetaNir
# iliapolo
# nija-at
# shivlaks
# skinny85
# SoManyHs
# sam-goodwin
# amui
# wleepang
# Athena96
# abhi7cr
# nimacks
# kahdojay
# taqumin
# umairishaq
# aditya187
# mooretom
# hariby
# shokout
# imadeit
# chamcca
# msambol
# LeahSiddall-aws
# kulpbenamazon
# CarmenAPuccio
# harusametime
# ohbuchim
# mpdominguez
# fernbach
# lopezfj
# rshalhoup
# monamo19
# svozza
# toksvaeth
# jayyeras
# rohitchandalurivt
# srikanth311
# Jeffwan
# tabern
# sthulb
# pahud
# vladvataws
# saselvan
# spaethp
# antovespoli
# dudutwizer
# khastation
# yuajia
# darwaishx
# ykbryan
# manavsehgal
# hangc27
# nmwalsh
# samuel-henry
# morrmt
# JunLyu
# jaipreet-s
# ZhangHan
# neelamgehlot
# Lstilwell
# mckev-amazon
# walkley
# pxaws
# pingleig
# hdj630
# gubupt
# zhoufang-joe
# tonynv
# eranation
# neillock
# mtalreja-a
# bnusunny
# zxkane
# huangzbaws
# nmoutschen
# billtarr-aws
# orchidmajumder
# tuliocasagrande
# tzvetkov75
# cassiamartin
# enr1c091
# trivikr
# AllanZhengYP
# seigenbrode
# PettitWesley
# mhausenblas
# xonor
# stevensu1977
# ykmr1224
# varunrao
# muhammadshahzad132
# rpcme
# zachgardner
# triggan
# YangFei1990
# pidajay
# cc4i
# ILAsoft
# guyilin-amazon
# butleragrant
# amzn-paunort
# allimn
# byronlin13
# justing-bq
# simonz-bq
# yohanmartin
# saumehta9
# othonrsanchez
# danieledwardknudsen
# sudhig
# gadams999
# jamesbland123
# balldarrens
# gizzigg
# alexw91
# bbutch
# andrewhop
# smrmkt
# obayk
# bosquu
# mkriaf
# kkvinjam
# jerwallace
# mm318
# AAlon
# squidbot
# willyg302
# wqfan
# valerena
# PatrickXYS
# aws-kf-ci-bot
# kpulavarti
# zhonghui12
# hossain-rayhan
# alexfrosa
# AndersAsa
# massi-ang
# JoeShi
# eamonnfaherty
# mckayjuk
# ritesh
# ConnorKirk
# jonrau-at-aws
# mithun008
# ccharro
# izaytsev
# zhizhongk
# sachgo
# rajpathi
# jkkorpi
# apekshajain
# smswz
# texastony
# josecorella
# lavaleri
# MatthewBennington
# scottarc
# ragona
# ajw-aws
# melodyyangaws
# kendrexs
# aurghob33
# anubhavynr
# idomic
# alpian
# alpamayo8848
# ilyabezdelev
# mrinaudo-aws
# JeremyJonas
# teuteuguy
# tstachlewski
# navbalaraman
# ckamps
# lalwanin2020
# deki
# nirozeri
# sankeyraut
# oranie-nrt
# mrahimi991
# studio3104
# dave-moser
# jimini55
# sudhirjena
# pmankad96
# pgjaiganesh
# Eric-Warehime
# amittal-amazon
# jasonumiker
# phmagic
# ariscris
# melchii
# dblock
# noahschwartz
# stefannatu
# shivaramani
# oweeen
# kareali
# MiaoZhangAWS
# matthewpaul
# HarshGandhi-AWS
# DavidOgunsAWS
# tgpadua
# jbesw
# julianwood
# gabrielmartinigit
# mzliang-annie
# surerahu
# itharavi
# ludvn
# JauntyWard
# changzcc
# shimeez
# basinr
# tlindsay42
# kolomied
# uttarasridhar
# edujanicas
# JgSeike
# joaoarag
# humank
# BalaRavilla
# Till--H
# cakepietoast
# billsnyder
# sujie2000
# csantos
# singledigit
# elangovana
# DanielYEHsieh
# switch180
# ctindel
# danielsyoder
# smsilb
# alaniyonu
# wingamajig
# ruslanafr
# mkhansenbot
# katakuji
# gibbster
# NRauschmayr
# srchase
# w601sxs
# osteffmann
# jeromevdl
# brianz
# billdoors
# cemsaz
# bwerness
# shuiwan
# bvitali
# samruthr
# ywang103
# juhoaws
# EmmanuelTsouris
# austoonz
# tpaulus
# cornickj
# farside5
# eidelmanjonathan
# davelemons
# Ryanjlowe
# jbernalvallejo
# bcelenza
# syrinx05p
# sjaffry
# dchenbec
# bahavar
# haozhouamzn
# mikames
# katallaxie
# verdimrc
# RaleighSF
# MyannaHarris
# rohkat-aws
# matlaver
# nvaidya1
# virgilvox
# disa6302
# hassanctech
# jdelapla
# MushMal
# lherman-cs
# yinsong1986
# loctrin
# mirelap-amazon
# gimki
# ivoanjo
# olivergillespie
# jamesoff
# virtlima
# lechmigdal
# omrahmed
# andysun2015
# anuranduttaroy
# codeslinger
# michaelmoussa
# zorrofox
# ganipcanot
# Joycehao19
# arhea
# rniksch
# Brian969
# hickeydh-aws
# rjjaegeraws
# archikierstead
# dliggat
# nachundu-amzn
# supergillis
# l2yao
# manishri-amzn
# FireballDWF
# fmcmac
# 0xjjoyy
# lazydragon
# achris
# ltrung
# michhyun1
# ziyiz-amzn
# simmkyu
# jing-chen1
# asnyatkov
# devalevenkatesh
# RidipDe
# p-foucht
# fabianmartins
# williams-katie
# n-mcf
# BastLeblanc
# manbearshark
# alexchirayath
# wongws
# dasmalini
# iannparker
# CFKevinRef
# ryanecrist
# bclymer
# tonyjin
# kazbaig
# ShivaniMehendarge
# rzhang74
# hokyungh
# zhinang-amazon
# dylonChime
# linsang21
# saidababu
# mhattiga
# yuxiny2586
# neer300
# johnBartos
# triha74
# andreivmaksimov
# afalzonelab
# aws-tec
# rcchakr
# aws-mafederi
# vidya-mohan
# iizus
# ahmedhany
# cgravani
# AhmedsZamzam
# laumcaicedo
# kashman-amzn
# StevenAskwith
# davidfsmith
# amit0701
# boringgeek
# saeedaghabozorgi
# markusz
# runpiw
# jkerste
# cjkindel
# giordzaws
# martinschaef
# sahilsareen
# mohsanjaffery
# jcriswell
# floydpink
# rafaelgsr
# horsfieldsa
# awsgrant
# redacted-aws
# banjyoti
# paulu-aws
# pnpolcher
# laithalsaadoon
# djjohnse
# bollig
# sean-smith
# amitmukh
# dchristian3188
# cbmcpeek
# yanivbos
# phillisf
# himantanna
# ivallhon
# tomfaulhaber
# nainkunal933
# nicklera1
# jayrao
# awserik
# kalawat1985
# kafka399
# tmcallaghan
# meet-bhagdev
# michaelraney
# lusoal
# kohidave
# AlcEccentric
# ChihaoSun123
# aamarnath2
# pokearu
# brightsparc
# ajkeane-aws
# jimhuangh
# mmatouk
# dleen
# perifaws
# mhuguesaws
# kraman-aws
# saitmiki
# flo-mair
# couchgott
# BenChaimberg
# noyceguy
# viyoma
# srijitm
# rohithcj
# llins
# linjungz
# bklein1
# gjoshevski
# glesch
# konduri
# awsimaya
# bonclay7
# amnevins
# vincentcabosart
# sameer-goel
# sahays
# itsaurabh1
# slee-aws
# mboulin
# mariswa
# parkand1
# regulusv
# alcousins
# jwilber
# andyhopp
# JarmanHauserAWS
# momonga-ml
# aldredb
# frbrkoala
# jaidisido
# vara-bonthu
# bishesh16
# HQarroum
# codingspirit
# santiagocardenas
# xuesichao
# evisb
# onsankawai
# daixba
# glennm1801
# andywick-aws
# pablods90
# marciogmorales
# tianyux-amz
# kaaaren
# giuseppeporcelli
# megahf
# jaknn
# frc9
# marinehadd
# usumfabricae
# annaluo676
# jonomon
# esplo
# purnesh
# mreferre
# SimonePomata
# pankajagrawal16
# sdmurphy-aws
# kwonyulchoi
# jakemraz
# abrenaut
# therealawsjoe
# wchaws
# logeshthedev
# niklongstone
# eugenemu
# surukonda
# avali-aws
# rickcao-aws
# abest0
# pavankumar2203
# andres-lindo
# ulili5
# neville-lewis
# AlexanderRichey
# sheldonlsides
# rafaelwmartins
# makvac-aws
# vasveena
# charliejllewellyn
# nakajiak
# nicolaven
# sanbrar
# guming3d
# Tessot
# suguiura-aws
# knizami
# bgiorgini
# kandha
# moagaber
# ibuchh
# flochaz
# AlexPinhel
# ijemmy
# asenousy
# bnurzhanov
# joshbean
# dbrown-git
# DrGranit
# forhead
# ndreasg
# sunbc0120
# awsandy
# eitansela
# annalyzin
# sgulbetekin
# clarchoiaws
# deepsihag
# brymrsh
# Othmane796
# vgribok
# dreamorosi
# sempfa
# mojodna
# CesarJava
# SuryaKari
# rafavallina
# JiahuiTao
# StevePotter
# abhivr-amazon
# awishn02
# brunormsilveira
# ranjith-aws
# tobuck-aws
# flamingofugang
# garzoand
# ycyang1229
# dast1
# claick-oliveira
# SofianHamiti
# ViktorMalesevic
# vitodegiosa
# spitzzz
# krithivasan
# jsteenblikaws
# keithaws
# realvz
# elamaran11
# spmunna
# mmaall
# casamson
# pmhargis-aws
# fnapolitano73
# hi4rahul
# virginiachu
# twitu
# dzeno
# rickybasse
# scottrfrancis
# asvand
# morrsing
# aharontwizer
# dashjim
# zhnc9
# lderryck
# malfree
# somujay
# pauljrob
# mteichtahl
# roman-boiko
# edwardps
# knaresh
# aws-kh
# rvanderwerf
# nikocuneo
# martenpayne
# bhouse99
# kmmahaj
# adriaandejonge
# mirgj
# johnmousa
# hoomanium
# darken99
# megareez
# yprikhodko
# petrokashlikov
# leschan
# swapandeep
# phiamazon
# bizzelicious
# rashedtalukder
# seanpmorgan
# c2tarun
# infinitydon
# p4cket
# newtondigital
# silvavb
# nsubrahm-aws
# jonslo
# premranga
# michaelhoarau
# jwoehrle
# mjkubba
# kwwendt
# raywang1021
# hariohmprasath
# hhkarimi
# timjbruce
# josiahdavis
# pvbouwel
# dancfox
# its-mirus-lu
# rstrahan
# syvanen
# vijayansarathy
# JustinCallison
# john-jac
# JoshB29
# rudpot
# prashanttct07
# lordjabez
# luchetto81
# kjacky
# yike5460
# dkheyman
# danieltet
# benscoterbk
# schuettc
# samsanders23
# vikeshpandey
# samir-souza
# mehdiaws
# ryanbrand
# sagulati
# emrnotebooks
# snehab14
# nicosang-aws
# MithilShah
# kcoleman731
# Zvikan
# askulkarni2
# UlaganathanNamachivayam
# automartin5000
# cheefoo
# sushanthmangalore
# paragbhingre
# allisaurus
# michaelhsieh42
# andskli
# pchot
# shahzadhuq
# mbednarzAWS
# valter-silva-au
# murtyc
# LeviSklaroff
# manasisurve
# harshitOberoi
# ldai1
# garyzhon
# dpwspoon
# adam-imeson
# vgkowski
# van-vothanh
# JasperW01
# crabba
# f7o
# weichihl
# awsa2ron
# kukielp
# literalice
# konokenj
# ohmurayu
# nabuskey
# vinayhanumaiah
# isaiahsal
# glyfnet
# t6nn
# maldalx
# be-meyer
# clinmatt
# gjohnson
# adhorn
# kaizio
# yiangmeng
# ferngus
# athewsey
# mznzhi
# hasanp87
# jeffsec-aws
# tmokmss
# zentahori
# akozd
# dooreaga
# fbouteruche
# melinaschweizer
# alex-m-aws
# Marinaburkhardt
# dylan-tong-aws
# oranie
# xparticle
# yapweiyih
# kkeli
# kthomas-amzn
# farrdoug
# hgrgic
# lpiedade
# karengryg
# diggory-briercliffe
# w0rks74710n
# davidhessler
# robbiecooray1
# code2648
# fbdo
# hkford
# str3tch
# tbrand
# wellsiau-aws
# nragusa
# sandeepveldi
# awssteph
# rsvenkatesh
# fl0yd
# mattegab
# virendhar-aws
# adampalm
# snvz
# cmlccie
# shapirov103
# durdina
# enricosarto
# nikaviam
# nitin-tiwari
# amirkaws
# aruthom
# adamandrewsaws
# t1agob
# samx18
# anandsakhare
# jdbean
# anujag24
# ItWillBeBetter
# SZubarev
# johnwalker00
# iankouls-aws
# pavlosik
# kazuhitogo
# caleighm
# gardnerjh
# drishtiarora
# MaitriJ
# georschi
# sheetaljoshi
# elviento
# julbeck
# markproy
# utsabroy
# frank-aws
# moonmaxw-aws
# tomhunte
# masangbeom
# CyranoB
# tuladp
# kanump
# rthamman
# jessieweiyi
# rahul-amzn
# omerh
# luisdant
# Julia-Bobo-Hu
# guisesterheim
# hemandee
# jplock
# kirit93
# durgasury
# joysl
# dpdornseifer
# shinka81
# kirankumar15
# miguelrc1
# swarwick
# dgallitelli
# danielhkt
# vaibhavjainv
# shamika
# bella-kwon
# ramy-nasreldin
# danielmatuki
# shashrv
# ram-shanmugam
# amineoualialami
# Jisoo-Min
# jon-peterson
# pk-jain
# juluriaj
# gi4nks
# dr-natetorious
# zacburns-aws
# rprentyaws
# Jerome-Pasini
# sfallahadl
# tamg-aws
# szvarun
# ganhuang
# rsmaso-aws
# jeanbaptisteguillois
# l-guida
# rajyaramazon
# ramvasi
# scotfe
# yanbasic
# Ming-J
# preethiratnam
# manshahe
# dmahapatro
# pforai
# sandeepgawande
# pragtideep
# jl4nz
# richardmilnerwatts
# pdifranc
# acere
# ahmedqe
# haofeif
# leelalagudu
# jmejco
# tamara-h
# shashivj
# gerrardcowburn
# boooziz
# cwalkere
# Josh-Bonello
# tdcsrq
# dcolcott
# rjesh-git
# alkayahan
# JuliaABurch
# rukekre
# brhook-aws
# kris-work
# haozhao-aws
# mj-ano
# senkinnar
# hemanthboinpally
# samvas-aws
# johnnyw-aws
# hanamz
# blayzestefaniak
# dilipmrajan9
# avisaws
# bestickley
# bpguasch
# nghtm
# lovaarte
# kulkarni-saurabh
# dabounds
# gherlein
# charlesg3
# dhawalkp
# dineshkumar4u
# msailes
# wangz10
# jeromeb
# gunnargrosch
# 982
# ['derisen' 'jmprieur' 'brandwe' 'oldalton' 'kaisong1990' 'danieldobalian'
#  'gsacavdm' 'kreedula' 'omercs' 'calvli' 'shawntabrizi' 'dstrockis'
#  'RideMo' 'pavankompelli' 'kalyankrishna1' 'TiagoBrenck' 'skwan'
#  'bgavrilMS' 'aremo-ms' 'libarson' 'tommoser' 'aashishr' 'kkanakas'
#  'bradsev' 'wguo123' 'deguhath' 'inchiosa' 'hangzh-msft' 'gopitk' 'Xue001'
#  'crwilcox' 'navyasric' 'jennyf19' 'DinoV' 'huguesv' 'tushargupta51'
#  'sgrebnov' 'paterasMSFT' 'dpwatrous' 'bgklein' 'matthchr' 'xingwu1'
#  'supernova-eng' 'alfpark' 'tamram' 'theunrepentantgeek' 'itowlson'
#  'jasper-schneider' 'annatisch' 'paselem' 'cwickham3' 'darylmsft'
#  'johnpapa' 'thepeekay' 'tdykstra' 'bradygaster-zz' 'BryanLa' 'lindydonna'
#  'ggailey777' 'kirillg' 'jongio' 'mhopkins-msft' 'perrysk-msft' 'robinsh'
#  'georgewallace' 'DavidCBerry13' 'emgerner-msft' 'dineshmurthy'
#  'SnehaGunda' 'anfeldma-ms' 'Mine-MSFT' 'arramac' 'mimig1' 'aliuy'
#  'burkeholland' 'AndrewHoh' 'dereklegenzoff' 'HeidiSteen' 'brjohnstmsft'
#  'liamca' 'olivierbloch' 'sraje' 'erikadoyle' 'vturecek' 'masnider'
#  'khenidak' 'seanmck' 'sangonzal' 'SomkaPe' 'Juliako' 'rloutlaw'
#  'Blackmist' 'spelluru' 'mikkelhegn' 'dkkapur' 'vipul-modi' 'PatAltimore'
#  'spyrossak' 'jtaubensee' 'VeronicaWasson' 'bennage' 'dominicbetts'
#  'alinapopa' 'VaijanathA' 'xiangyan99' 'nicolehaugen' 'HaishiBai'
#  'jamesmontemagno' 'pierceboggan' 'harikmenon' 'Minewiskan' 'kraigb'
#  'johndeu' 'dagalvao' 'henryt-ms' 'ningl2' 'Lichard' 'rajputam' 'lmazuel'
#  'hegate' 'AttunixCorp' 'Ilias-Tsigkogiannis' 'mamokarz' 'cephalin'
#  'micurd' 'pmaytak' 'trwalke' 'SameerK-MSFT' 'neha-bhargava'
#  'aiwangmicrosoft' 'codemillmatt' 'parakhj' 'henrik-me' 'vibronet'
#  'gilitaragano' 'ali-hamud' 't-yoigra' 'MahirDiab' 'eligr' 'noanu'
#  'mattmazzola' 'wbreza' 'sarangan12' 'vishrutshah' 'devigned'
#  'anudeepsharma' 'martinsawicki' 'anuchandy' 'selvasingh' 'ericlgf'
#  'allclark' 'yoelhor' 'agrabhi' 'stevenxzhou' 'BarbaraSelden' 'rojasja'
#  'omer-iqbal' 'amarzavery' 'szhaomsft' 'yinhew' 'yulin-li' 'boltomli'
#  'neoguo0601' 'jasonvomsft' 'delfu' 'stevchin' 'lightfrenzy'
#  'eduardkoller' 'diberry' 'berndverst' 'wolfma61' 'alvadb' 't-olhuan'
#  'haocs' 'gladjohn' 'mcardosos' 'rban1' 'brianrandell' 'idg10' 'clemensv'
#  'jhendrixMSFT' 'marstr' 'rapatchi' 'suhuruli' 'sayantancs' 'vishnumane'
#  'raunakpandya' 'PinkySingh' 'abhishekram' 'aashiman' 'roygara' 'SyntaxC4'
#  'hovsepm' 'jianghaolu' 'seguler' 'sptramer' 'bharath-microsoft'
#  'maburlik' 'deepakjangid-MSFT' 'hrushib' 'saveenr' 'prashanthyv'
#  'balajikris' 'gandhinath' 'edhagan' 'shizn' 'xscript' 'yuwzho' 'yaweiw'
#  'xpouyat' 'shigeyf' 'jihwang0709' 'hrasheed-msft' 'dhgoelmsft'
#  'JasonWHowell' 'rajanikanthr' 'duggaraju' 'vinaysurya' 'MaximRouiller'
#  'zivraf' 'MauricioMolinaMicrosoft' 'msfussell' 'v-mankan' 'v-rakesc'
#  'v-payech' 'v-payc' 'carlrab' 'dbradish-microsoft' 'sdwheeler'
#  'erickson-doug' 'steved0x' 'sankethka' 'czeumault' 'daschult'
#  'ZhijunZhao' 'yungez' 'SLdragon' 'SummerSun' 'moprescu' 'drwill-ms'
#  'ericmitt' 'wesmc7777' 'yzhong94' 'valnav' 'saraford' 'WodansSon'
#  'JunyiYi' 'furqanMM' 'Om83' 'unpluggedk' 'rlagh2' 'ritwik20' 'tudordid'
#  'vDonGlover' 'xseeseesee' 'EdPrice-MSFT' 'michthub' 'bretthackermsft'
#  'ktsakas' 'umabal' 'vigunase' 'schaabs' 'mipetriu' 'jasoncoolmax'
#  'mahilleb-msft' 'raaaar' 'RaviPidaparthi' 'splusq' 'radiocom' 'sameerag'
#  'mmacy' 'negoe' 'omkarmore83' 'yaronyg' 'LuisBosquez' 'sivethe'
#  'deborahc' 'Shama-K' 'michaeljqzq' 'guanyu-240' 'pkanher617'
#  'KevinBlasko' 'gucalder' 'nzthiago' 'milismsft' 'neilpeterson'
#  'guyinacube' 'sirui-sun' 'rwike77' 'tiffanyachen' 'fhokholdMSFT'
#  'karataliu' 'peterpogorski' 'ailn' 'zr-msft' 'iainfoulds'
#  'efficienthacks' 'richardjortega' 'Prozac777' 'smichelotti' 'SunBuild'
#  'v-royhar' 'clarkio' 'veronicagg' 'lenala' 'TsuyoshiUshio'
#  'christopheranderson' 'jeffhollan' 'banisadr' 'nonik0' 'varunsh-coder'
#  'linya9191' 'rastala' 'daden-ms' 'hning86' 'mezmicrosoft' 'ehrlinger'
#  'jaymathe' 'pechyony' 'xibingaomsft' 'mohabdel2013' 'mithun-prasad'
#  'kojiwms' 'overbrimming' 'gokhanuluderya-msft' 'philon-msft'
#  'brendanzagaeski' 'warrenzhu25' 'ArcturusZhang' 'Alancere' 'mybayern1974'
#  'vladbarosan' 'joshgav' 'yangyuan' 'sudhansu88' 'kirthik' 'areddish'
#  'DavidLiCIG' 'stefanvalianu' 'IanB111' 'ashika789' 'chasat-ms'
#  'yeskarthik' 'Sandip-Raiyani' 'dmdenmsft' 'ankryach' 'kanshiG' 'kansrini'
#  'aahill' 'v-jaswel' 'wiazur' 'assafi' 'erhopf' 'kpajdzik' 'williexu'
#  'weidongxu-microsoft' 'PatrickFarley' 'olduroja' 'iscai-msft'
#  'FrancescaLazzeri' 'shonohs' 'craftyhouse' 'anantshankar17' 'Nickomang'
#  'ChackDan' 'mwinkle' 'rguthriemsft' 'gled4er' 'laujan' 'ChrisHMSFT'
#  'xinyzhou' 'gowthu2712' 'nitinme' 'MikeDodaro' 'ramya-rao-a' 'gavinfish'
#  'zikalino' 'yungezz' 'kyliel' 'Duffney' 'laurenhughes' 'dlepow'
#  'anthonychu' 'lbugnion' 'Careyjmac' 'erich-wang' 'Lusitanian' 'dragav'
#  'mmyyrroonn' 'jonpayne' 'vidhoonv' 'craigshoemaker' 'jluk'
#  'FabianMeiswinkel' 'vivekr20' 'moderakh' 'alch-msft' 'gk-8' 'OGcanviz'
#  'KarlErickson' 'abhidnya13' 'ericwol-msft' 'jebrando' 'elhorton'
#  'pierreca' 'OguzPastirmaci' 'odaibert' 'mattreatMSFT' 'CamSoper'
#  'caleteeter' 'shrugupt' 'aishik-pyne' 'ramyapradhan' 'theMobiusStrip'
#  'sidkri' 'imnaseer' 'ali92hm' 'codyborn' 'mmercuri' 'brendalee'
#  'cnsegura' 'hthatukuru' 'grcignav' 'azabbasi' 'timtay-microsoft'
#  'jamdavi' 'abhipsaMisra' 'vinagesh' 'bikamani' 'barustum'
#  'prmathur-microsoft' 'davilu' 'CIPop' 'jenoola' 'az-iot-builder-01'
#  'jasmineymlo' 'cartertinney' 'glharper' 'dargilco' 'glecaros' 'chschrae'
#  'BrianMouncer' 'HenryvanderVegte' 'PanosPeriorellis' 'rhurey'
#  'shiwenmichael' 'oscholz' 'bexxx' 'chlandsi' 'amitkumarshukla'
#  'zhouwangzw' 'RichardSunMS' 'ahamad-MS' 'kalyanaj' 'DariuszPorowski'
#  'BSamodien' 'dmckinstry' 'dtzar' 'dcaro' 'apraovjr' 'mwasham'
#  'HuapingLiu' 'jychoudh' 'JingliLin2018' 'huamingwang' 'sarahlume'
#  'WSturman' 'kukramer' 'ongk' 'jessebenson' 'brian-swan' 'j-martens'
#  'brminnick' 'rbrundritt' 'dasanagu' 'msangapu-msft' 'pargall' 'ihvo'
#  'paladique' 'btholt' 'priyaananthasankar' 'ebertrams' 'm-chau' 'sridmad'
#  'TylerMSFT' 'vishaltmsft' 't-kusing-msft' 'sahithikkss' 'hemantkathuria'
#  'msmbaldwin' 'jayantacs' 'kjilla' 'ealsur' 'brunoborges' 'markjbrown'
#  'srchi' 'serenadavis' 'PascaHabineza' 'devki98' 'baanders'
#  'KingdomOfEnds' 'philmea' 'JosephPaulAntonetti' 'dsk-2015'
#  'fernandoviton' 'alinamstanciu' 'andyatwork' 'asw101' 'dbarkol'
#  'stevebus' 'grdinin' 'edburns' 'sadigopu' 'northtyphoon' 'SteveLasker'
#  'tobaiMS' 'yihezkel' 'mgblythe' 'lachie83' 'rbitia' 'jeremyrickard'
#  'v-michaelmi' 'anagha-microsoft' 'algattik' 'benjguin' 'yorek'
#  'chetanmsft' 'amat27' 'abbhar' 'viananth' 'dkershaw10' 'WilliamBerryiii'
#  'angellmethod' 'druttka' 'Gaploid' 'brusMX' 'TheOnlyWei' 'seyadava'
#  'scottcate' 'JKrame' 'mregen' 'luiscantero' 'hansgschossmann'
#  'simonjaeger' 'peterbryntesson' 'blackchoey' 'donghexu' 'bganapa'
#  'saragluna' 'paulbouwer' 'wuchiehhan' 'BoyaXie' 'cyhuang01' 'junjieqian'
#  'kbrowne8' 'roy-har' 'kirankumarkolli' 'JMayrbaeurl' 'samkreter'
#  'brendan-src' 'HenrikFrystykNielsen' 'sidprasad' 'j82w' 'Sammak'
#  'MS-Santi' 'theresapalmer' 'sharonlo101' 'billgib' 'cmcclister' 'jpiyali'
#  'markwolff' 'hectorhdzg' 'gogowings' 'akirakakar' 'rtanase' 'drajput'
#  'mmydland' 'jlian' 'wviriya' 'joelhulen' 'bhummerstone' 'RenaShahMSFT'
#  'jeffpatt24' 'YunZhou-MS' 'surendernitj' 'rohiths-msft' 'ledavies'
#  'wmgries' 'sprasad-microsoft' 'YoDaMa' 'tylerfox' 'idear1203' 'conhua'
#  'moreOver0' 'mrbullwinkle' 'Kerly1' 'BrianPeek' 'surnaik'
#  'aim-for-better' 'maliksahil' 'anrothMSFT' 'paledger' 'msha1026'
#  'IngridAtMicrosoft' 'BrianBlum' 'giakas' 'sebader' 'jennifermarsman'
#  'LuisCabrer' 'cynotebo' 'soophiac' 'tyclintw' 'mandyshieh' 'edjez'
#  'CarlosP-MS' 'srswamy-msft' 'JasenLassig' 'penorouzi' 'initmahesh'
#  'misainat' 'rlfmendes' 'anjayajodha' 'rtibi' 'garvitarai' 'sijuman'
#  'deveshguha' 'pkshultz' 'cschotte' 'walsehgal' 'Avery-Dunn' 'idg-sam'
#  'cindydeng1998' 'bleroy' 'vkurpad' 'jadrefke' 'juanjperez' 'cjoakim'
#  'Rodrigossz' 'ThomasWeiss' 'victor-meng' 'srinathnarayanan'
#  'TheovanKraay' 'ramrajprabu' 'jdubois' 'riserrad' 'fiveisprime'
#  'rachel-msft' 'shahzaibj' 'rpdome' 'iambmelt' 'hamiltonha' 'ecfan'
#  'scgbear' 'brandonh-msft' 'fsharpn00b' 'anatolip' 'AdelGhabboun'
#  'paulomarquesc' 'fehase' 'cfialkiewicz' 'dagiro' 'amenarde'
#  'manashgoswami' 'apulliam' 'liydu' 'hellyzh' 'DCtheGeek' 'aflinchb'
#  'devwag' 'bartr' 'rayluo' 'JerryYangKai' 'IvanJobs' 'arsenvlad' 'dadihe'
#  'yaozjalex' 'shoatman' 'leonard520' 'yucwan' 'metacpp' 'xgugeng'
#  'robotdad' 'stack111' 'vyta' 'jsturtevant' 'k-bren' 'babbageclunk'
#  'frodopwns' 'melonrush13' 'jpflueger' 'dobrzyn2' 'kushagraThapar'
#  'ramsessanchez' 'baywet' 'ramya25' 'tshaiman' 'Itnorman' 'nofaredanoren'
#  'fvneerden' 'uratzmon' 'oriziv' 'sapinderpalsingh' 'promisinganuj'
#  'jmostella' 'devlace' 'sinnypan' 'siliang-j-1225' 'gary918' 'shervyna'
#  'ydaponte' 'DavidBurela' 'satonaoki' 'Nick287' 'thurstonchen'
#  'swetha-sundar' 'maye-msft' 'andrewdyhhub' 'namitms' 'jsburckhardt'
#  'icchan' 'NT-D' 'xinsnake' 'tomomi-code' 'Azadehkhojandi' 'Herman-Wu'
#  'deniscep' 'kiwibayer' 'hannesne' 'M-Hietala' 'jiamguo' 'singhsaumya'
#  'eikim' 'olmidy' 'encorona-ms' 'mswellsi' 'ovishesh' 'qfweiwei'
#  'splumber' 'JPalmerDev' 'cfogg6' 'trrwilson' 'BhramaraA' 'mydiemho'
#  'alkofahi' 'Humoiz' 'michaeldeongreen' 'aluong' 'kln4dt' 'idavis'
#  'wduraes' 'niachary' 'alkohli' 'raviprpandey' 'neerajdixit-msft'
#  'vikask77' 'priestlg' 'Teodelas' 'onaim-msft' 'jasonnutter' 'fedeoliv'
#  'allantargino' 'sffamily' 'andxu' 'Flanker32' 'N-Usha' 'SergeyKanzhelev'
#  'lzchen' 'paloukari' 'michielvanschaik' 'myamama' 'katriendg' 'vslepakov'
#  'arlotito' 'jovanpop-msft' 'Niharikadutta' 'ruixinxu' 'Jing29'
#  'kaiyuezhou' 'TwoUnder' 'rapoth' 'midesa' 'MikeRys' 'euangms'
#  'rasavant-ms' 'David-Noble-at-work' 'gukoff' 'TechPreacher' 'fbeltrao'
#  'revinjchalil' 'CodeRunRepeat' 'normesta' 'twooley' 'danhellem'
#  'alexkarcher-msft' 'DeepikaSadahiro' 'cschormann' 'anaharris-ms'
#  'rolucchi' 'kayousef' 'a-noyass' 'AmirGeorge' 'AndyCW' 'Joll59'
#  'KatieProchilo' 'cmayomsft' 'cmaneu' 'manishmsfte' 'vjrantal' 'Sarah-Aly'
#  'msyyc' 'nickzhums' '00Kai0' 'gansvv' 'poanchen' 'cjpfaff' 'CloudViking'
#  'elnica6-zz' 'mcollier' 'luleonpla' 'gio-rdz' 'cljung' 'mahoekst'
#  'darsney' 'ccrowley96' 'jamiewilbraham' 'rinisbet' 'jamescarpinter'
#  'balansubr' 'johnsta' 'arjunattam' 'grayzu' 'nickgmicrosoft' 'jgardner04'
#  'yashkv1' 'neeginotra' 'xboxeer' 'usvoyager' 'majguo' 'zhengchang907'
#  'grrlgeek' 'maxmushkin' 'omidm1' 'mamccrea' 'NickDrouin' 'hildurhodd'
#  'haukurstefansson' 'mssindhurid' 'gkostal' 'kroshkina-ms'
#  'priyanka-gomatam' 'adesh-rao' 'prabdeb' 'brijrajsingh' 'danewalton'
#  'randywu763' 'ryanwinter' 'nkhuyent' 'JasonFreeberg' 'khaosdoctor'
#  'mikebudzynski' 'mpapas' 'cpeeyush' 'agowdamsft' 'MicrosoftGuyJFlo'
#  'oliviajain' 'wmpauli' 'pragyaaneja' 'Pengpeng-Microsoft' 'tle15'
#  'anjuligoring' 'salsal97' 'marvinbuss' 'vivishno' 'ddematheu2'
#  'prprabhu-ms' 'cwhil2492' 'ravithanneeru' 'xumo-95' 'juancamilor'
#  'pavelprystinka' 'zihzhan-msft' 'raosanat' 'palatter' 'LoadLibrary'
#  'iaulakh' 'kagbakpem' 'alkwa-msft' 'PorterNan' 'JamesBurnside'
#  'alex-kwan' 'ashwinder' 'lei-msft' 'tophpalmer' 'fizampou' 'srasool'
#  'jyotsnaravikumar' 'edaena' 'helayoty' 'samiyaakhtar' 'evanlouie'
#  'bnookala' 'keianasnell' 'akatesmith' 'saraswatshantanu' 'nyanzebra'
#  'bospoort' 'elmouzak' 'cippero' 'ralarcon' 'vermegi' 'tnorling'
#  'jo-arroyo' 'niswitze' 'qiaozha' 'akhilayesantarao' 'JoshuaLai' 'AmyL219'
#  'JohnVUgonabo' 'cheukchuen' 'jimchou-dev' 'Gemakk' 'waynemo' 'Yonet'
#  'gachandw' 'mimckitt' 'agoncal' 'mnriem' 'anandchugh' 'msbinli'
#  'abhirockzz' 'trevorbye' 'tasdevani21' 'norelina' 'LaunaKay' 'ikivanc'
#  'olasowemimo' 'paolosalvatori' 'AdinaTru' 'issacnitin' 'Mrayyan'
#  'phileo99' 'lpx1989' 'amthomas46' 'lfitchett' 'bkuriach' 'annamnara'
#  'nicjohn79' 'xgerman' 'hihigupt' 'ewertons' 'dzsquared' 'naiteeks'
#  'nikitapitliya' 'nicolasbotto' 'marvin-garcia' 'puicchan' 'trask'
#  'hui1110' 'backwind1233' 'chenrujun' 'yiliuTo' 'stliu' 'mrm9084'
#  'jialigit' 'zhichengliu12581' 'WentingWu666666' 'kyle-patterson'
#  'danieloh30' 'jamesfalkner' 'joshlong' 'mootpointer' 'dhruvchand'
#  'mksuni' 'xfz11' 'srkalava' 'chgeuer' 'ckittel' 'ferantivero' 'mscurrell'
#  'AriZavala2' '1iveowl' 'lanicolas']
# derisen
# jmprieur
# brandwe
# oldalton
# kaisong1990
# danieldobalian
# gsacavdm
# kreedula
# omercs
# calvli
# shawntabrizi
# dstrockis
# RideMo
# pavankompelli
# kalyankrishna1
# TiagoBrenck
# skwan
# bgavrilMS
# aremo-ms
# libarson
# tommoser
# aashishr
# kkanakas
# bradsev
# wguo123
# deguhath
# inchiosa
# hangzh-msft
# gopitk
# Xue001
# crwilcox
# navyasric
# jennyf19
# DinoV
# huguesv
# tushargupta51
# sgrebnov
# paterasMSFT
# dpwatrous
# bgklein
# matthchr
# xingwu1
# supernova-eng
# alfpark
# tamram
# theunrepentantgeek
# itowlson
# jasper-schneider
# annatisch
# paselem
# cwickham3
# darylmsft
# johnpapa
# thepeekay
# tdykstra
# bradygaster-zz
# BryanLa
# lindydonna
# ggailey777
# kirillg
# jongio
# mhopkins-msft
# perrysk-msft
# robinsh
# georgewallace
# DavidCBerry13
# emgerner-msft
# dineshmurthy
# SnehaGunda
# anfeldma-ms
# Mine-MSFT
# arramac
# mimig1
# aliuy
# burkeholland
# AndrewHoh
# dereklegenzoff
# HeidiSteen
# brjohnstmsft
# liamca
# olivierbloch
# sraje
# erikadoyle
# vturecek
# masnider
# khenidak
# seanmck
# sangonzal
# SomkaPe
# Juliako
# rloutlaw
# Blackmist
# spelluru
# mikkelhegn
# dkkapur
# vipul-modi
# PatAltimore
# spyrossak
# jtaubensee
# VeronicaWasson
# bennage
# dominicbetts
# alinapopa
# VaijanathA
# xiangyan99
# nicolehaugen
# HaishiBai
# jamesmontemagno
# pierceboggan
# harikmenon
# Minewiskan
# kraigb
# johndeu
# dagalvao
# henryt-ms
# ningl2
# Lichard
# rajputam
# lmazuel
# hegate
# AttunixCorp
# Ilias-Tsigkogiannis
# mamokarz
# cephalin
# micurd
# pmaytak
# trwalke
# SameerK-MSFT
# neha-bhargava
# aiwangmicrosoft
# codemillmatt
# parakhj
# henrik-me
# vibronet
# gilitaragano
# ali-hamud
# t-yoigra
# MahirDiab
# eligr
# noanu
# mattmazzola
# wbreza
# sarangan12
# vishrutshah
# devigned
# anudeepsharma
# martinsawicki
# anuchandy
# selvasingh
# ericlgf
# allclark
# yoelhor
# agrabhi
# stevenxzhou
# BarbaraSelden
# rojasja
# omer-iqbal
# amarzavery
# szhaomsft
# yinhew
# yulin-li
# boltomli
# neoguo0601
# jasonvomsft
# delfu
# stevchin
# lightfrenzy
# eduardkoller
# diberry
# berndverst
# wolfma61
# alvadb
# t-olhuan
# haocs
# gladjohn
# mcardosos
# rban1
# brianrandell
# idg10
# clemensv
# jhendrixMSFT
# marstr
# rapatchi
# suhuruli
# sayantancs
# vishnumane
# raunakpandya
# PinkySingh
# abhishekram
# aashiman
# roygara
# SyntaxC4
# hovsepm
# jianghaolu
# seguler
# sptramer
# bharath-microsoft
# maburlik
# deepakjangid-MSFT
# hrushib
# saveenr
# prashanthyv
# balajikris
# gandhinath
# edhagan
# shizn
# xscript
# yuwzho
# yaweiw
# xpouyat
# shigeyf
# jihwang0709
# hrasheed-msft
# dhgoelmsft
# JasonWHowell
# rajanikanthr
# duggaraju
# vinaysurya
# MaximRouiller
# zivraf
# MauricioMolinaMicrosoft
# msfussell
# v-mankan
# v-rakesc
# v-payech
# v-payc
# carlrab
# dbradish-microsoft
# sdwheeler
# erickson-doug
# steved0x
# sankethka
# czeumault
# daschult
# ZhijunZhao
# yungez
# SLdragon
# SummerSun
# moprescu
# drwill-ms
# ericmitt
# wesmc7777
# yzhong94
# valnav
# saraford
# WodansSon
# JunyiYi
# furqanMM
# Om83
# unpluggedk
# rlagh2
# ritwik20
# tudordid
# vDonGlover
# xseeseesee
# EdPrice-MSFT
# michthub
# bretthackermsft
# ktsakas
# umabal
# vigunase
# schaabs
# mipetriu
# jasoncoolmax
# mahilleb-msft
# raaaar
# RaviPidaparthi
# splusq
# radiocom
# sameerag
# mmacy
# negoe
# omkarmore83
# yaronyg
# LuisBosquez
# sivethe
# deborahc
# Shama-K
# michaeljqzq
# guanyu-240
# pkanher617
# KevinBlasko
# gucalder
# nzthiago
# milismsft
# neilpeterson
# guyinacube
# sirui-sun
# rwike77
# tiffanyachen
# fhokholdMSFT
# karataliu
# peterpogorski
# ailn
# zr-msft
# iainfoulds
# efficienthacks
# richardjortega
# Prozac777
# smichelotti
# SunBuild
# v-royhar
# clarkio
# veronicagg
# lenala
# TsuyoshiUshio
# christopheranderson
# jeffhollan
# banisadr
# nonik0
# varunsh-coder
# linya9191
# rastala
# daden-ms
# hning86
# mezmicrosoft
# ehrlinger
# jaymathe
# pechyony
# xibingaomsft
# mohabdel2013
# mithun-prasad
# kojiwms
# overbrimming
# gokhanuluderya-msft
# philon-msft
# brendanzagaeski
# warrenzhu25
# ArcturusZhang
# Alancere
# mybayern1974
# vladbarosan
# joshgav
# yangyuan
# sudhansu88
# kirthik
# areddish
# DavidLiCIG
# stefanvalianu
# IanB111
# ashika789
# chasat-ms
# yeskarthik
# Sandip-Raiyani
# dmdenmsft
# ankryach
# kanshiG
# kansrini
# aahill
# v-jaswel
# wiazur
# assafi
# erhopf
# kpajdzik
# williexu
# weidongxu-microsoft
# PatrickFarley
# olduroja
# iscai-msft
# FrancescaLazzeri
# shonohs
# craftyhouse
# anantshankar17
# Nickomang
# ChackDan
# mwinkle
# rguthriemsft
# gled4er
# laujan
# ChrisHMSFT
# xinyzhou
# gowthu2712
# nitinme
# MikeDodaro
# ramya-rao-a
# gavinfish
# zikalino
# yungezz
# kyliel
# Duffney
# laurenhughes
# dlepow
# anthonychu
# lbugnion
# Careyjmac
# erich-wang
# Lusitanian
# dragav
# mmyyrroonn
# jonpayne
# vidhoonv
# craigshoemaker
# jluk
# FabianMeiswinkel
# vivekr20
# moderakh
# alch-msft
# gk-8
# OGcanviz
# KarlErickson
# abhidnya13
# ericwol-msft
# jebrando
# elhorton
# pierreca
# OguzPastirmaci
# odaibert
# mattreatMSFT
# CamSoper
# caleteeter
# shrugupt
# aishik-pyne
# ramyapradhan
# theMobiusStrip
# sidkri
# imnaseer
# ali92hm
# codyborn
# mmercuri
# brendalee
# cnsegura
# hthatukuru
# grcignav
# azabbasi
# timtay-microsoft
# jamdavi
# abhipsaMisra
# vinagesh
# bikamani
# barustum
# prmathur-microsoft
# davilu
# CIPop
# jenoola
# az-iot-builder-01
# jasmineymlo
# cartertinney
# glharper
# dargilco
# glecaros
# chschrae
# BrianMouncer
# HenryvanderVegte
# PanosPeriorellis
# rhurey
# shiwenmichael
# oscholz
# bexxx
# chlandsi
# amitkumarshukla
# zhouwangzw
# RichardSunMS
# ahamad-MS
# kalyanaj
# DariuszPorowski
# BSamodien
# dmckinstry
# dtzar
# dcaro
# apraovjr
# mwasham
# HuapingLiu
# jychoudh
# JingliLin2018
# huamingwang
# sarahlume
# WSturman
# kukramer
# ongk
# jessebenson
# brian-swan
# j-martens
# brminnick
# rbrundritt
# dasanagu
# msangapu-msft
# pargall
# ihvo
# paladique
# btholt
# priyaananthasankar
# ebertrams
# m-chau
# sridmad
# TylerMSFT
# vishaltmsft
# t-kusing-msft
# sahithikkss
# hemantkathuria
# msmbaldwin
# jayantacs
# kjilla
# ealsur
# brunoborges
# markjbrown
# srchi
# serenadavis
# PascaHabineza
# devki98
# baanders
# KingdomOfEnds
# philmea
# JosephPaulAntonetti
# dsk-2015
# fernandoviton
# alinamstanciu
# andyatwork
# asw101
# dbarkol
# stevebus
# grdinin
# edburns
# sadigopu
# northtyphoon
# SteveLasker
# tobaiMS
# yihezkel
# mgblythe
# lachie83
# rbitia
# jeremyrickard
# v-michaelmi
# anagha-microsoft
# algattik
# benjguin
# yorek
# chetanmsft
# amat27
# abbhar
# viananth
# dkershaw10
# WilliamBerryiii
# angellmethod
# druttka
# Gaploid
# brusMX
# TheOnlyWei
# seyadava
# scottcate
# JKrame
# mregen
# luiscantero
# hansgschossmann
# simonjaeger
# peterbryntesson
# blackchoey
# donghexu
# bganapa
# saragluna
# paulbouwer
# wuchiehhan
# BoyaXie
# cyhuang01
# junjieqian
# kbrowne8
# roy-har
# kirankumarkolli
# JMayrbaeurl
# samkreter
# brendan-src
# HenrikFrystykNielsen
# sidprasad
# j82w
# Sammak
# MS-Santi
# theresapalmer
# sharonlo101
# billgib
# cmcclister
# jpiyali
# markwolff
# hectorhdzg
# gogowings
# akirakakar
# rtanase
# drajput
# mmydland
# jlian
# wviriya
# joelhulen
# bhummerstone
# RenaShahMSFT
# jeffpatt24
# YunZhou-MS
# surendernitj
# rohiths-msft
# ledavies
# wmgries
# sprasad-microsoft
# YoDaMa
# tylerfox
# idear1203
# conhua
# moreOver0
# mrbullwinkle
# Kerly1
# BrianPeek
# surnaik
# aim-for-better
# maliksahil
# anrothMSFT
# paledger
# msha1026
# IngridAtMicrosoft
# BrianBlum
# giakas
# sebader
# jennifermarsman
# LuisCabrer
# cynotebo
# soophiac
# tyclintw
# mandyshieh
# edjez
# CarlosP-MS
# srswamy-msft
# JasenLassig
# penorouzi
# initmahesh
# misainat
# rlfmendes
# anjayajodha
# rtibi
# garvitarai
# sijuman
# deveshguha
# pkshultz
# cschotte
# walsehgal
# Avery-Dunn
# idg-sam
# cindydeng1998
# bleroy
# vkurpad
# jadrefke
# juanjperez
# cjoakim
# Rodrigossz
# ThomasWeiss
# victor-meng
# srinathnarayanan
# TheovanKraay
# ramrajprabu
# jdubois
# riserrad
# fiveisprime
# rachel-msft
# shahzaibj
# rpdome
# iambmelt
# hamiltonha
# ecfan
# scgbear
# brandonh-msft
# fsharpn00b
# anatolip
# AdelGhabboun
# paulomarquesc
# fehase
# cfialkiewicz
# dagiro
# amenarde
# manashgoswami
# apulliam
# liydu
# hellyzh
# DCtheGeek
# aflinchb
# devwag
# bartr
# rayluo
# JerryYangKai
# IvanJobs
# arsenvlad
# dadihe
# yaozjalex
# shoatman
# leonard520
# yucwan
# metacpp
# xgugeng
# robotdad
# stack111
# vyta
# jsturtevant
# k-bren
# babbageclunk
# frodopwns
# melonrush13
# jpflueger
# dobrzyn2
# kushagraThapar
# ramsessanchez
# baywet
# ramya25
# tshaiman
# Itnorman
# nofaredanoren
# fvneerden
# uratzmon
# oriziv
# sapinderpalsingh
# promisinganuj
# jmostella
# devlace
# sinnypan
# siliang-j-1225
# gary918
# shervyna
# ydaponte
# DavidBurela
# satonaoki
# Nick287
# thurstonchen
# swetha-sundar
# maye-msft
# andrewdyhhub
# namitms
# jsburckhardt
# icchan
# NT-D
# xinsnake
# tomomi-code
# Azadehkhojandi
# Herman-Wu
# deniscep
# kiwibayer
# hannesne
# M-Hietala
# jiamguo
# singhsaumya
# eikim
# olmidy
# encorona-ms
# mswellsi
# ovishesh
# qfweiwei
# splumber
# JPalmerDev
# cfogg6
# trrwilson
# BhramaraA
# mydiemho
# alkofahi
# Humoiz
# michaeldeongreen
# aluong
# kln4dt
# idavis
# wduraes
# niachary
# alkohli
# raviprpandey
# neerajdixit-msft
# vikask77
# priestlg
# Teodelas
# onaim-msft
# jasonnutter
# fedeoliv
# allantargino
# sffamily
# andxu
# Flanker32
# N-Usha
# SergeyKanzhelev
# lzchen
# paloukari
# michielvanschaik
# myamama
# katriendg
# vslepakov
# arlotito
# jovanpop-msft
# Niharikadutta
# ruixinxu
# Jing29
# kaiyuezhou
# TwoUnder
# rapoth
# midesa
# MikeRys
# euangms
# rasavant-ms
# David-Noble-at-work
# gukoff
# TechPreacher
# fbeltrao
# revinjchalil
# CodeRunRepeat
# normesta
# twooley
# danhellem
# alexkarcher-msft
# DeepikaSadahiro
# cschormann
# anaharris-ms
# rolucchi
# kayousef
# a-noyass
# AmirGeorge
# AndyCW
# Joll59
# KatieProchilo
# cmayomsft
# cmaneu
# manishmsfte
# vjrantal
# Sarah-Aly
# msyyc
# nickzhums
# 00Kai0
# gansvv
# poanchen
# cjpfaff
# CloudViking
# elnica6-zz
# mcollier
# luleonpla
# gio-rdz
# cljung
# mahoekst
# darsney
# ccrowley96
# jamiewilbraham
# rinisbet
# jamescarpinter
# balansubr
# johnsta
# arjunattam
# grayzu
# nickgmicrosoft
# jgardner04
# yashkv1
# neeginotra
# xboxeer
# usvoyager
# majguo
# zhengchang907
# grrlgeek
# maxmushkin
# omidm1
# mamccrea
# NickDrouin
# hildurhodd
# haukurstefansson
# mssindhurid
# gkostal
# kroshkina-ms
# priyanka-gomatam
# adesh-rao
# prabdeb
# brijrajsingh
# danewalton
# randywu763
# ryanwinter
# nkhuyent
# JasonFreeberg
# khaosdoctor
# mikebudzynski
# mpapas
# cpeeyush
# agowdamsft
# MicrosoftGuyJFlo
# oliviajain
# wmpauli
# pragyaaneja
# Pengpeng-Microsoft
# tle15
# anjuligoring
# salsal97
# marvinbuss
# vivishno
# ddematheu2
# prprabhu-ms
# cwhil2492
# ravithanneeru
# xumo-95
# juancamilor
# pavelprystinka
# zihzhan-msft
# raosanat
# palatter
# LoadLibrary
# iaulakh
# kagbakpem
# alkwa-msft
# PorterNan
# JamesBurnside
# alex-kwan
# ashwinder
# lei-msft
# tophpalmer
# fizampou
# srasool
# jyotsnaravikumar
# edaena
# helayoty
# samiyaakhtar
# evanlouie
# bnookala
# keianasnell
# akatesmith
# saraswatshantanu
# nyanzebra
# bospoort
# elmouzak
# cippero
# ralarcon
# vermegi
# tnorling
# jo-arroyo
# niswitze
# qiaozha
# akhilayesantarao
# JoshuaLai
# AmyL219
# JohnVUgonabo
# cheukchuen
# jimchou-dev
# Gemakk
# waynemo
# Yonet
# gachandw
# mimckitt
# agoncal
# mnriem
# anandchugh
# msbinli
# abhirockzz
# trevorbye
# tasdevani21
# norelina
# LaunaKay
# ikivanc
# olasowemimo
# paolosalvatori
# AdinaTru
# issacnitin
# Mrayyan
# phileo99
# lpx1989
# amthomas46
# lfitchett
# bkuriach
# annamnara
# nicjohn79
# xgerman
# hihigupt
# ewertons
# dzsquared
# naiteeks
# nikitapitliya
# nicolasbotto
# marvin-garcia
# puicchan
# trask
# hui1110
# backwind1233
# chenrujun
# yiliuTo
# stliu
# mrm9084
# jialigit
# zhichengliu12581
# WentingWu666666
# kyle-patterson
# danieloh30
# jamesfalkner
# joshlong
# mootpointer
# dhruvchand
# mksuni
# xfz11
# srkalava
# chgeuer
# ckittel
# ferantivero
# mscurrell
# AriZavala2
# 1iveowl
# lanicolas
# 27
# ['Buzzardo' 'dsyer' 'martinlippert' 'gregturn' 'bclozel' 'royclarkson'
#  'cbeams' 'snicoll' 'habuma' 'jzheaux' 'artembilan' 'marcingrzejszczak'
#  'benas' 'jxblum' 'garyrussell' 'mp911de' 'unscriptable' 'briancavalier'
#  'jvalkeal' 'ryanjbaxter' 'mstahv' 'fhanik' 'joshlong' 'sdeleuze'
#  'OlgaMaciaszek' 'dturanski' 'OlegDokuka']
# Buzzardo
# dsyer
# martinlippert
# gregturn
# bclozel
# royclarkson
# cbeams
# snicoll
# habuma
# jzheaux
# artembilan
# marcingrzejszczak
# benas
# jxblum
# garyrussell
# mp911de
# unscriptable
# briancavalier
# jvalkeal
# ryanjbaxter
# mstahv
# fhanik
# joshlong
# sdeleuze
# OlgaMaciaszek
# dturanski
# OlegDokuka

# %%
df_google.to_csv("../2-AggregateData/googleMaintainers_exclude_internal_pulls.csv")

# %%
df_aws.to_csv("../2-AggregateData/awsMaintainers_exclude_internal_pulls.csv")

# %%
df_azure.to_csv("../2-AggregateData/azureMaintainers_exclude_internal_pulls.csv")

# %%
df_spring.to_csv("../2-AggregateData/springMaintainers_exclude_internal_pulls.csv")
