# %%
pip install PyGithub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from github import Github
g = Github("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")

#h = Github("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")
#i = Github("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")
#j = Github("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")
#k = Github("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")
print(g.get_rate_limit().core.remaining)
#print(h.get_rate_limit().core.remaining)
#print(i.get_rate_limit().core.remaining)
#print(j.get_rate_limit().core.remaining)
#print(k.get_rate_limit().core.remaining)
import pandas as pd
# Out:
# 430

# %%
samples = pd.read_csv("../1-ExtractDataPrs/Data2022/googleteste2022.csv")

# %%
#del samples["New Column Title"]
#del samples["Unnamed: 0"]

# %%
samples["framework"].size
# Out:
# 878

# %%
def getRepoInfos(link):
  link_quebrado = link.split("/")
  numero_do_pull = link_quebrado.pop(len(link_quebrado)-1)
  sample = link_quebrado.pop(len(link_quebrado)-2)
  owner = link_quebrado.pop(len(link_quebrado)-2)
  nome_repositorio =  owner + "/" + sample
  return numero_do_pull, nome_repositorio

# %%
def checkKeyChange():
    global g #,h,i,k...z
    aux = Github("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")
    while(True):
      if aux.get_rate_limit().core.remaining > 100:
        g = aux
        #print("first key " + str(g.get_rate_limit()))
        break
      #elif h.get_rate_limit().core.remaining > 100:
       # g = h
        #print("trocou h " + str(g.get_rate_limit()))
       # break
     # elif i.get_rate_limit().core.remaining > 100:
      #  g = i
        #print("trocou i " + str(g.get_rate_limit()))
       # break
     # elif j.get_rate_limit().core.remaining > 100:
      #  g = j
        #print("trocou i " + str(g.get_rate_limit()))
       # break  
      #elif k.get_rate_limit().core.remaining > 100:
       # g = k
        #print("trocou i " + str(g.get_rate_limit()))
       # break    
      else:
        print("Key limit exceeded waiting...")

# %%
def main():

  global g
  nome_do_repositorio = ""
  repositorio = object
  for line in range(0,samples["framework"].size):
    
    checkKeyChange()
    print(g.get_rate_limit())
    print(f"{line} / {samples['framework'].size}")
    pull = samples.iloc[line]
    numero_do_pull, nome_do_repositorio = getRepoInfos(pull["link"])
    try:
      pull_objeto = g.get_repo(nome_do_repositorio).get_pull(int(numero_do_pull)) #repositorio.get_pull(int(numero_do_pull))
      #user = pull_objeto.user
      totalReview = 0
      revisoresLogin = ''
      totalReview = pull_objeto.get_reviews().totalCount
      userReviewApproved =  ''
      userClosed = ''
      for review in pull_objeto.get_reviews():  
            revisoresLogin = revisoresLogin + " " + review.user.login
            #print(review.user.login)  
            if review.state == "APPROVED":
              userReviewApproved = review.user
      if pull_objeto.closed_at != '' and pull_objeto.closed_at is not None:
        userClosed = pull_objeto.as_issue().closed_by

       
      samples.loc[line, "closed user cargo"] = userClosed.role if userClosed  != '' else ""
      samples.loc[line, "closed user empresa"] = userClosed.company if userClosed  != '' else ""
      samples.loc[line, "closed user local"] = userClosed.location if userClosed  != '' else ""
      samples.loc[line, "closed user login"] = userClosed.login if userClosed  != '' else ""
      samples.loc[line, "closed user email"] = userClosed.email if userClosed  != '' else ""
      samples.loc[line, "closed user seguidores"] = userClosed.followers if userClosed  != '' else ""
     

      #samples.loc[line, "closed user tempo no GitHub"] = (pull_objeto.created_at - user.created_at).days
      samples.loc[line, "total de reviews"] = totalReview
      samples.loc[line,"revisores login"] = revisoresLogin
      
      
      samples.loc[line, "review approved user cargo"] = userReviewApproved.role  if userReviewApproved != '' else ""
      samples.loc[line, "review approved user empresa"] = userReviewApproved.company if userReviewApproved != '' else ""
      samples.loc[line, "review approved user local"] = userReviewApproved.location if userReviewApproved != '' else ""
      samples.loc[line, "review approved user login"] = userReviewApproved.login if userReviewApproved != '' else ""
      samples.loc[line, "review approved user email"] = userReviewApproved.email if userReviewApproved != '' else ""
      samples.loc[line, "review approved user seguidores"] = userReviewApproved.followers if userReviewApproved != '' else ""
      

    except:
      print(nome_do_repositorio, numero_do_pull,"erro")

  samples.to_csv("../1-ExtractDataPrs/Data2022/googleteste2022.csv", index=False)

# %%
if __name__ == "__main__":
    main()
# Out:
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=430, limit=5000))
# 0 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=423, limit=5000))
# 1 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=417, limit=5000))
# 2 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=410, limit=5000))
# 3 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=406, limit=5000))
# 4 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=402, limit=5000))
# 5 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=396, limit=5000))
# 6 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=390, limit=5000))
# 7 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=384, limit=5000))
# 8 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=380, limit=5000))
# 9 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=374, limit=5000))
# 10 / 878
# ...
