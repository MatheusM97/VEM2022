# %%
pip install PyGithub
# Out:
# Requirement already satisfied: PyGithub in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (1.55)
# Requirement already satisfied: pyjwt>=2.0 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from PyGithub) (2.4.0)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from PyGithub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from PyGithub) (2.28.1)
# Requirement already satisfied: deprecated in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from PyGithub) (1.2.13)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from pynacl>=1.4.0->PyGithub) (1.15.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.14.0->PyGithub) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.14.0->PyGithub) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.14.0->PyGithub) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.14.0->PyGithub) (1.26.11)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from deprecated->PyGithub) (1.14.1)
# Requirement already satisfied: pycparser in c:\users\mathe\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from github import Github
#insert token on variable g,hi,j...z

g = Github("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") 

#h = Github("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") token expired
#i = Github("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") token expired
#j = Github("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") token expired
#k = Github("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") token expired
#print(g.get_rate_limit().core.remaining)
print(g.get_rate_limit().core.remaining)
#print(i.get_rate_limit().core.remaining)
#print(j.get_rate_limit().core.remaining)
#print(k.get_rate_limit().core.remaining)
import pandas as pd
# Out:
# 3064

# %%
samples = pd.read_csv("../1-ExtractDataPrs/Data2022/googleteste2022.csv")

# %%
#del samples["New Column Title"]
del samples["Unnamed: 0"]

# %%
samples["framework"].size
# Out:
# 878

# %%
def getRepoInfos(link):
  link_quebrado = link.split("/")
  numero_do_pull = link_quebrado.pop(len(link_quebrado)-1)
  sample = link_quebrado.pop(len(link_quebrado)-2)
  owner = link_quebrado.pop(len(link_quebrado)-2)
  nome_repositorio =  owner + "/" + sample
  return numero_do_pull, nome_repositorio

# %%
def checkKeyChange():
    global g #,h,i,k...z
    aux = Github("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")
    while(True):
      if aux.get_rate_limit().core.remaining > 100:
        g = aux
        #print("first key " + str(g.get_rate_limit()))
        break
      #elif h.get_rate_limit().core.remaining > 100:
       # g = h
        #print("trocou h " + str(g.get_rate_limit()))
       # break
     # elif i.get_rate_limit().core.remaining > 100:
      #  g = i
        #print("trocou i " + str(g.get_rate_limit()))
       # break
     # elif j.get_rate_limit().core.remaining > 100:
      #  g = j
        #print("trocou i " + str(g.get_rate_limit()))
       # break  
      #elif k.get_rate_limit().core.remaining > 100:
       # g = k
        #print("trocou i " + str(g.get_rate_limit()))
       # break    
      else:
        print("Key limit exceeded waiting...")

# %%
global g
nome_do_repositorio = "" #repositoryName
repositorio = object #repository
for line in range(0,samples["framework"].size):
  
  checkKeyChange()
  print(g.get_rate_limit())
  print(f"{line} / {samples['framework'].size}")
  pull = samples.iloc[line]
  numero_do_pull, nome_do_repositorio = getRepoInfos(pull["link"])
  try:
    pull_objeto = g.get_repo(nome_do_repositorio).get_pull(int(numero_do_pull)) #repositorio.get_pull(int(numero_do_pull))
    user = pull_objeto.user
     

    samples.loc[line, "creator user cargo"] = user.role
    samples.loc[line, "creator user empresa"] = user.company
    samples.loc[line, "creator user local"] = user.location
    samples.loc[line, "creator user login"] = user.login
    samples.loc[line, "creator user email"] = user.email
    samples.loc[line, "creator user seguidores"] = user.followers
    samples.loc[line, "creator user tempo no GitHub"] = (pull_objeto.created_at - user.created_at).days
  except:
    print(nome_do_repositorio, numero_do_pull,"error")
# Out:
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3064, limit=5000))
# 0 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3061, limit=5000))
# 1 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3058, limit=5000))
# 2 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3055, limit=5000))
# 3 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3052, limit=5000))
# 4 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3049, limit=5000))
# 5 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3046, limit=5000))
# 6 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3043, limit=5000))
# 7 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3040, limit=5000))
# 8 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3037, limit=5000))
# 9 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3034, limit=5000))
# 10 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3031, limit=5000))
# 11 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3028, limit=5000))
# 12 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3025, limit=5000))
# 13 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3022, limit=5000))
# 14 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3019, limit=5000))
# 15 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3016, limit=5000))
# 16 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3013, limit=5000))
# 17 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3010, limit=5000))
# 18 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3007, limit=5000))
# 19 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3004, limit=5000))
# 20 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=3001, limit=5000))
# 21 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2998, limit=5000))
# 22 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2995, limit=5000))
# 23 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2992, limit=5000))
# 24 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2989, limit=5000))
# 25 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2986, limit=5000))
# 26 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2983, limit=5000))
# 27 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2980, limit=5000))
# 28 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2977, limit=5000))
# 29 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2974, limit=5000))
# 30 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2971, limit=5000))
# 31 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2968, limit=5000))
# 32 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2965, limit=5000))
# 33 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2962, limit=5000))
# 34 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2959, limit=5000))
# 35 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2956, limit=5000))
# 36 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2953, limit=5000))
# 37 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2950, limit=5000))
# 38 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2947, limit=5000))
# 39 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2944, limit=5000))
# 40 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2941, limit=5000))
# 41 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2938, limit=5000))
# 42 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2935, limit=5000))
# 43 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2932, limit=5000))
# 44 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2929, limit=5000))
# 45 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2926, limit=5000))
# 46 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2923, limit=5000))
# 47 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2920, limit=5000))
# 48 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2917, limit=5000))
# 49 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2914, limit=5000))
# 50 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2911, limit=5000))
# 51 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2908, limit=5000))
# 52 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2905, limit=5000))
# 53 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2902, limit=5000))
# 54 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2899, limit=5000))
# 55 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2896, limit=5000))
# 56 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2893, limit=5000))
# 57 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2890, limit=5000))
# 58 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2887, limit=5000))
# 59 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2884, limit=5000))
# 60 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2881, limit=5000))
# 61 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2878, limit=5000))
# 62 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2875, limit=5000))
# 63 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2872, limit=5000))
# 64 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2869, limit=5000))
# 65 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2866, limit=5000))
# 66 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2863, limit=5000))
# 67 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2860, limit=5000))
# 68 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2857, limit=5000))
# 69 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2854, limit=5000))
# 70 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2851, limit=5000))
# 71 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2848, limit=5000))
# 72 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2845, limit=5000))
# 73 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2842, limit=5000))
# 74 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2839, limit=5000))
# 75 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2836, limit=5000))
# 76 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2833, limit=5000))
# 77 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2830, limit=5000))
# 78 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2827, limit=5000))
# 79 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2824, limit=5000))
# 80 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2821, limit=5000))
# 81 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2818, limit=5000))
# 82 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2815, limit=5000))
# 83 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2812, limit=5000))
# 84 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2809, limit=5000))
# 85 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2806, limit=5000))
# 86 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2803, limit=5000))
# 87 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2800, limit=5000))
# 88 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2797, limit=5000))
# 89 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2794, limit=5000))
# 90 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2791, limit=5000))
# 91 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2788, limit=5000))
# 92 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2785, limit=5000))
# 93 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2782, limit=5000))
# 94 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2779, limit=5000))
# 95 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2776, limit=5000))
# 96 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2773, limit=5000))
# 97 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2770, limit=5000))
# 98 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2767, limit=5000))
# 99 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2764, limit=5000))
# 100 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2761, limit=5000))
# 101 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2758, limit=5000))
# 102 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2755, limit=5000))
# 103 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2752, limit=5000))
# 104 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2749, limit=5000))
# 105 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2746, limit=5000))
# 106 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2743, limit=5000))
# 107 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2740, limit=5000))
# 108 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2737, limit=5000))
# 109 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2734, limit=5000))
# 110 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2731, limit=5000))
# 111 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2728, limit=5000))
# 112 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2725, limit=5000))
# 113 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2722, limit=5000))
# 114 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2719, limit=5000))
# 115 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2716, limit=5000))
# 116 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2713, limit=5000))
# 117 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2710, limit=5000))
# 118 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2707, limit=5000))
# 119 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2704, limit=5000))
# 120 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2701, limit=5000))
# 121 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2698, limit=5000))
# 122 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2695, limit=5000))
# 123 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2692, limit=5000))
# 124 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2689, limit=5000))
# 125 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2686, limit=5000))
# 126 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2683, limit=5000))
# 127 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2680, limit=5000))
# 128 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2677, limit=5000))
# 129 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2674, limit=5000))
# 130 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2671, limit=5000))
# 131 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2668, limit=5000))
# 132 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2665, limit=5000))
# 133 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2662, limit=5000))
# 134 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2659, limit=5000))
# 135 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2656, limit=5000))
# 136 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2653, limit=5000))
# 137 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2650, limit=5000))
# 138 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2647, limit=5000))
# 139 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2644, limit=5000))
# 140 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2641, limit=5000))
# 141 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2638, limit=5000))
# 142 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2635, limit=5000))
# 143 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2632, limit=5000))
# 144 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2629, limit=5000))
# 145 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2626, limit=5000))
# 146 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2623, limit=5000))
# 147 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2620, limit=5000))
# 148 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2617, limit=5000))
# 149 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2614, limit=5000))
# 150 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2611, limit=5000))
# 151 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2608, limit=5000))
# 152 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2605, limit=5000))
# 153 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2602, limit=5000))
# 154 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2599, limit=5000))
# 155 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2596, limit=5000))
# 156 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2593, limit=5000))
# 157 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2590, limit=5000))
# 158 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2587, limit=5000))
# 159 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2584, limit=5000))
# 160 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2581, limit=5000))
# 161 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2578, limit=5000))
# 162 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2575, limit=5000))
# 163 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2572, limit=5000))
# 164 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2569, limit=5000))
# 165 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2566, limit=5000))
# 166 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2563, limit=5000))
# 167 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2560, limit=5000))
# 168 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2557, limit=5000))
# 169 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2554, limit=5000))
# 170 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2551, limit=5000))
# 171 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2548, limit=5000))
# 172 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2545, limit=5000))
# 173 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2542, limit=5000))
# 174 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2539, limit=5000))
# 175 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2536, limit=5000))
# 176 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2533, limit=5000))
# 177 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2530, limit=5000))
# 178 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2527, limit=5000))
# 179 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2524, limit=5000))
# 180 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2521, limit=5000))
# 181 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2518, limit=5000))
# 182 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2515, limit=5000))
# 183 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2512, limit=5000))
# 184 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2509, limit=5000))
# 185 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2506, limit=5000))
# 186 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2503, limit=5000))
# 187 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2500, limit=5000))
# 188 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2497, limit=5000))
# 189 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2494, limit=5000))
# 190 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2491, limit=5000))
# 191 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2488, limit=5000))
# 192 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2485, limit=5000))
# 193 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2482, limit=5000))
# 194 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2479, limit=5000))
# 195 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2476, limit=5000))
# 196 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2473, limit=5000))
# 197 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2470, limit=5000))
# 198 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2467, limit=5000))
# 199 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2464, limit=5000))
# 200 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2461, limit=5000))
# 201 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2458, limit=5000))
# 202 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2455, limit=5000))
# 203 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2452, limit=5000))
# 204 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2449, limit=5000))
# 205 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2446, limit=5000))
# 206 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2443, limit=5000))
# 207 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2440, limit=5000))
# 208 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2437, limit=5000))
# 209 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2434, limit=5000))
# 210 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2431, limit=5000))
# 211 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2428, limit=5000))
# 212 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2425, limit=5000))
# 213 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2422, limit=5000))
# 214 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2419, limit=5000))
# 215 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2416, limit=5000))
# 216 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2413, limit=5000))
# 217 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2410, limit=5000))
# 218 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2407, limit=5000))
# 219 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2404, limit=5000))
# 220 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2401, limit=5000))
# 221 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2398, limit=5000))
# 222 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2395, limit=5000))
# 223 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2392, limit=5000))
# 224 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2389, limit=5000))
# 225 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2386, limit=5000))
# 226 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2383, limit=5000))
# 227 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2380, limit=5000))
# 228 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2377, limit=5000))
# 229 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2374, limit=5000))
# 230 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2371, limit=5000))
# 231 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2368, limit=5000))
# 232 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2365, limit=5000))
# 233 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2362, limit=5000))
# 234 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2359, limit=5000))
# 235 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2356, limit=5000))
# 236 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2353, limit=5000))
# 237 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2350, limit=5000))
# 238 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2347, limit=5000))
# 239 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2344, limit=5000))
# 240 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2341, limit=5000))
# 241 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2338, limit=5000))
# 242 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2335, limit=5000))
# 243 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2332, limit=5000))
# 244 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2329, limit=5000))
# 245 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2326, limit=5000))
# 246 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2323, limit=5000))
# 247 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2320, limit=5000))
# 248 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2317, limit=5000))
# 249 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2314, limit=5000))
# 250 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2311, limit=5000))
# 251 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2308, limit=5000))
# 252 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2305, limit=5000))
# 253 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2302, limit=5000))
# 254 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2299, limit=5000))
# 255 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2296, limit=5000))
# 256 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2293, limit=5000))
# 257 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2290, limit=5000))
# 258 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2287, limit=5000))
# 259 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2284, limit=5000))
# 260 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2281, limit=5000))
# 261 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2278, limit=5000))
# 262 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2275, limit=5000))
# 263 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2272, limit=5000))
# 264 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2269, limit=5000))
# 265 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2266, limit=5000))
# 266 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2263, limit=5000))
# 267 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2260, limit=5000))
# 268 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2257, limit=5000))
# 269 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2254, limit=5000))
# 270 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2251, limit=5000))
# 271 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2248, limit=5000))
# 272 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2245, limit=5000))
# 273 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2242, limit=5000))
# 274 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2239, limit=5000))
# 275 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2236, limit=5000))
# 276 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2233, limit=5000))
# 277 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2230, limit=5000))
# 278 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2227, limit=5000))
# 279 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2224, limit=5000))
# 280 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2221, limit=5000))
# 281 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2218, limit=5000))
# 282 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2215, limit=5000))
# 283 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2212, limit=5000))
# 284 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2209, limit=5000))
# 285 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2206, limit=5000))
# 286 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2203, limit=5000))
# 287 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2200, limit=5000))
# 288 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2197, limit=5000))
# 289 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2194, limit=5000))
# 290 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2191, limit=5000))
# 291 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2188, limit=5000))
# 292 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2185, limit=5000))
# 293 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2182, limit=5000))
# 294 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2179, limit=5000))
# 295 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2176, limit=5000))
# 296 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2173, limit=5000))
# 297 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2170, limit=5000))
# 298 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2167, limit=5000))
# 299 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2164, limit=5000))
# 300 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2161, limit=5000))
# 301 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2158, limit=5000))
# 302 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2155, limit=5000))
# 303 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2152, limit=5000))
# 304 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2149, limit=5000))
# 305 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2146, limit=5000))
# 306 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2143, limit=5000))
# 307 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2140, limit=5000))
# 308 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2137, limit=5000))
# 309 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2134, limit=5000))
# 310 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2131, limit=5000))
# 311 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2128, limit=5000))
# 312 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2125, limit=5000))
# 313 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2122, limit=5000))
# 314 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2119, limit=5000))
# 315 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2116, limit=5000))
# 316 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2113, limit=5000))
# 317 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2110, limit=5000))
# 318 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2107, limit=5000))
# 319 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2104, limit=5000))
# 320 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2101, limit=5000))
# 321 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2098, limit=5000))
# 322 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2095, limit=5000))
# 323 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2092, limit=5000))
# 324 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2089, limit=5000))
# 325 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2086, limit=5000))
# 326 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2083, limit=5000))
# 327 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2080, limit=5000))
# 328 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2077, limit=5000))
# 329 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2074, limit=5000))
# 330 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2071, limit=5000))
# 331 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2068, limit=5000))
# 332 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2065, limit=5000))
# 333 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2062, limit=5000))
# 334 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2059, limit=5000))
# 335 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2056, limit=5000))
# 336 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2053, limit=5000))
# 337 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2050, limit=5000))
# 338 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2047, limit=5000))
# 339 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2044, limit=5000))
# 340 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2041, limit=5000))
# 341 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2038, limit=5000))
# 342 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2035, limit=5000))
# 343 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2032, limit=5000))
# 344 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2029, limit=5000))
# 345 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2026, limit=5000))
# 346 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2023, limit=5000))
# 347 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2020, limit=5000))
# 348 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2017, limit=5000))
# 349 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2014, limit=5000))
# 350 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2011, limit=5000))
# 351 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2008, limit=5000))
# 352 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2005, limit=5000))
# 353 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=2002, limit=5000))
# 354 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1999, limit=5000))
# 355 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1996, limit=5000))
# 356 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1993, limit=5000))
# 357 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1990, limit=5000))
# 358 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1987, limit=5000))
# 359 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1984, limit=5000))
# 360 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1981, limit=5000))
# 361 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1978, limit=5000))
# 362 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1975, limit=5000))
# 363 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1972, limit=5000))
# 364 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1969, limit=5000))
# 365 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1966, limit=5000))
# 366 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1963, limit=5000))
# 367 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1960, limit=5000))
# 368 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1957, limit=5000))
# 369 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1954, limit=5000))
# 370 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1951, limit=5000))
# 371 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1948, limit=5000))
# 372 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1945, limit=5000))
# 373 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1942, limit=5000))
# 374 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1939, limit=5000))
# 375 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1936, limit=5000))
# 376 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1933, limit=5000))
# 377 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1930, limit=5000))
# 378 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1927, limit=5000))
# 379 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1924, limit=5000))
# 380 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1921, limit=5000))
# 381 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1918, limit=5000))
# 382 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1915, limit=5000))
# 383 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1912, limit=5000))
# 384 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1909, limit=5000))
# 385 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1906, limit=5000))
# 386 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1903, limit=5000))
# 387 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1900, limit=5000))
# 388 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1897, limit=5000))
# 389 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1894, limit=5000))
# 390 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1891, limit=5000))
# 391 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1888, limit=5000))
# 392 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1885, limit=5000))
# 393 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1882, limit=5000))
# 394 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1879, limit=5000))
# 395 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1876, limit=5000))
# 396 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1873, limit=5000))
# 397 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1870, limit=5000))
# 398 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1867, limit=5000))
# 399 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1864, limit=5000))
# 400 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1861, limit=5000))
# 401 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1858, limit=5000))
# 402 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1855, limit=5000))
# 403 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1852, limit=5000))
# 404 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1849, limit=5000))
# 405 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1846, limit=5000))
# 406 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1843, limit=5000))
# 407 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1840, limit=5000))
# 408 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1837, limit=5000))
# 409 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1834, limit=5000))
# 410 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1831, limit=5000))
# 411 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1828, limit=5000))
# 412 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1825, limit=5000))
# 413 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1822, limit=5000))
# 414 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1819, limit=5000))
# 415 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1816, limit=5000))
# 416 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1813, limit=5000))
# 417 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1810, limit=5000))
# 418 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1807, limit=5000))
# 419 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1804, limit=5000))
# 420 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1801, limit=5000))
# 421 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1798, limit=5000))
# 422 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1795, limit=5000))
# 423 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1792, limit=5000))
# 424 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1789, limit=5000))
# 425 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1786, limit=5000))
# 426 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1783, limit=5000))
# 427 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1780, limit=5000))
# 428 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1777, limit=5000))
# 429 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1774, limit=5000))
# 430 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1771, limit=5000))
# 431 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1768, limit=5000))
# 432 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1765, limit=5000))
# 433 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1762, limit=5000))
# 434 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1759, limit=5000))
# 435 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1756, limit=5000))
# 436 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1753, limit=5000))
# 437 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1750, limit=5000))
# 438 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1747, limit=5000))
# 439 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1744, limit=5000))
# 440 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1741, limit=5000))
# 441 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1738, limit=5000))
# 442 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1735, limit=5000))
# 443 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1732, limit=5000))
# 444 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1729, limit=5000))
# 445 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1726, limit=5000))
# 446 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1723, limit=5000))
# 447 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1720, limit=5000))
# 448 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1717, limit=5000))
# 449 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1714, limit=5000))
# 450 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1711, limit=5000))
# 451 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1708, limit=5000))
# 452 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1705, limit=5000))
# 453 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1702, limit=5000))
# 454 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1699, limit=5000))
# 455 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1696, limit=5000))
# 456 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1693, limit=5000))
# 457 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1690, limit=5000))
# 458 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1687, limit=5000))
# 459 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1684, limit=5000))
# 460 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1681, limit=5000))
# 461 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1678, limit=5000))
# 462 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1675, limit=5000))
# 463 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1672, limit=5000))
# 464 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1669, limit=5000))
# 465 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1666, limit=5000))
# 466 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1663, limit=5000))
# 467 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1660, limit=5000))
# 468 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1657, limit=5000))
# 469 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1654, limit=5000))
# 470 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1651, limit=5000))
# 471 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1648, limit=5000))
# 472 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1645, limit=5000))
# 473 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1642, limit=5000))
# 474 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1639, limit=5000))
# 475 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1636, limit=5000))
# 476 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1633, limit=5000))
# 477 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1630, limit=5000))
# 478 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1627, limit=5000))
# 479 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1624, limit=5000))
# 480 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1621, limit=5000))
# 481 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1618, limit=5000))
# 482 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1615, limit=5000))
# 483 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1612, limit=5000))
# 484 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1609, limit=5000))
# 485 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1606, limit=5000))
# 486 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1603, limit=5000))
# 487 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1600, limit=5000))
# 488 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1597, limit=5000))
# 489 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1594, limit=5000))
# 490 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1591, limit=5000))
# 491 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1588, limit=5000))
# 492 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1585, limit=5000))
# 493 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1582, limit=5000))
# 494 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1579, limit=5000))
# 495 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1576, limit=5000))
# 496 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1573, limit=5000))
# 497 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1570, limit=5000))
# 498 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1567, limit=5000))
# 499 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1564, limit=5000))
# 500 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1561, limit=5000))
# 501 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1558, limit=5000))
# 502 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1555, limit=5000))
# 503 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1552, limit=5000))
# 504 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1549, limit=5000))
# 505 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1546, limit=5000))
# 506 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1543, limit=5000))
# 507 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1540, limit=5000))
# 508 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1537, limit=5000))
# 509 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1534, limit=5000))
# 510 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1531, limit=5000))
# 511 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1528, limit=5000))
# 512 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1525, limit=5000))
# 513 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1522, limit=5000))
# 514 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1519, limit=5000))
# 515 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1516, limit=5000))
# 516 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1513, limit=5000))
# 517 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1510, limit=5000))
# 518 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1507, limit=5000))
# 519 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1504, limit=5000))
# 520 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1501, limit=5000))
# 521 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1498, limit=5000))
# 522 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1495, limit=5000))
# 523 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1492, limit=5000))
# 524 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1489, limit=5000))
# 525 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1486, limit=5000))
# 526 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1483, limit=5000))
# 527 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1480, limit=5000))
# 528 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1477, limit=5000))
# 529 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1474, limit=5000))
# 530 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1471, limit=5000))
# 531 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1468, limit=5000))
# 532 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1465, limit=5000))
# 533 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1462, limit=5000))
# 534 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1459, limit=5000))
# 535 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1456, limit=5000))
# 536 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1453, limit=5000))
# 537 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1450, limit=5000))
# 538 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1447, limit=5000))
# 539 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1444, limit=5000))
# 540 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1441, limit=5000))
# 541 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1438, limit=5000))
# 542 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1435, limit=5000))
# 543 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1432, limit=5000))
# 544 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1429, limit=5000))
# 545 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1426, limit=5000))
# 546 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1423, limit=5000))
# 547 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1420, limit=5000))
# 548 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1417, limit=5000))
# 549 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1414, limit=5000))
# 550 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1411, limit=5000))
# 551 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1408, limit=5000))
# 552 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1405, limit=5000))
# 553 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1402, limit=5000))
# 554 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1399, limit=5000))
# 555 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1396, limit=5000))
# 556 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1393, limit=5000))
# 557 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=1390, limit=5000))
# 558 / 878
# ...
# 689 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=994, limit=5000))
# 690 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=991, limit=5000))
# 691 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=988, limit=5000))
# 692 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=985, limit=5000))
# 693 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=982, limit=5000))
# 694 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=979, limit=5000))
# 695 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=976, limit=5000))
# 696 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=973, limit=5000))
# 697 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=970, limit=5000))
# 698 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=967, limit=5000))
# 699 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=964, limit=5000))
# 700 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=961, limit=5000))
# 701 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=958, limit=5000))
# 702 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=955, limit=5000))
# 703 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=952, limit=5000))
# 704 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=949, limit=5000))
# 705 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=946, limit=5000))
# 706 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=943, limit=5000))
# 707 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=940, limit=5000))
# 708 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=937, limit=5000))
# 709 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=934, limit=5000))
# 710 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=931, limit=5000))
# 711 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=928, limit=5000))
# 712 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=925, limit=5000))
# 713 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=922, limit=5000))
# 714 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=919, limit=5000))
# 715 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=916, limit=5000))
# 716 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=913, limit=5000))
# 717 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=910, limit=5000))
# 718 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=907, limit=5000))
# 719 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=904, limit=5000))
# 720 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=901, limit=5000))
# 721 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=898, limit=5000))
# 722 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=895, limit=5000))
# 723 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=892, limit=5000))
# 724 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=889, limit=5000))
# 725 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=886, limit=5000))
# 726 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=883, limit=5000))
# 727 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=880, limit=5000))
# 728 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=877, limit=5000))
# 729 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=874, limit=5000))
# 730 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=871, limit=5000))
# 731 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=868, limit=5000))
# 732 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=865, limit=5000))
# 733 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=862, limit=5000))
# 734 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=859, limit=5000))
# 735 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=856, limit=5000))
# 736 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=853, limit=5000))
# 737 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=850, limit=5000))
# 738 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=847, limit=5000))
# 739 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=844, limit=5000))
# 740 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=841, limit=5000))
# 741 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=838, limit=5000))
# 742 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=835, limit=5000))
# 743 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=832, limit=5000))
# 744 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=829, limit=5000))
# 745 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=826, limit=5000))
# 746 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=823, limit=5000))
# 747 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=820, limit=5000))
# 748 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=817, limit=5000))
# 749 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=814, limit=5000))
# 750 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=811, limit=5000))
# 751 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=808, limit=5000))
# 752 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=805, limit=5000))
# 753 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=802, limit=5000))
# 754 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=799, limit=5000))
# 755 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=796, limit=5000))
# 756 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=793, limit=5000))
# 757 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=790, limit=5000))
# 758 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=787, limit=5000))
# 759 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=784, limit=5000))
# 760 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=781, limit=5000))
# 761 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=778, limit=5000))
# 762 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=775, limit=5000))
# 763 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=772, limit=5000))
# 764 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=769, limit=5000))
# 765 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=766, limit=5000))
# 766 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=763, limit=5000))
# 767 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=760, limit=5000))
# 768 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=757, limit=5000))
# 769 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=754, limit=5000))
# 770 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=751, limit=5000))
# 771 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=748, limit=5000))
# 772 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=745, limit=5000))
# 773 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=742, limit=5000))
# 774 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=739, limit=5000))
# 775 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=736, limit=5000))
# 776 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=733, limit=5000))
# 777 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=730, limit=5000))
# 778 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=727, limit=5000))
# 779 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=724, limit=5000))
# 780 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=721, limit=5000))
# 781 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=718, limit=5000))
# 782 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=715, limit=5000))
# 783 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=712, limit=5000))
# 784 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=709, limit=5000))
# 785 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=706, limit=5000))
# 786 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=703, limit=5000))
# 787 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=700, limit=5000))
# 788 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=697, limit=5000))
# 789 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=694, limit=5000))
# 790 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=691, limit=5000))
# 791 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=688, limit=5000))
# 792 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=685, limit=5000))
# 793 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=682, limit=5000))
# 794 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=679, limit=5000))
# 795 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=676, limit=5000))
# 796 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=673, limit=5000))
# 797 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=670, limit=5000))
# 798 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=667, limit=5000))
# 799 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=664, limit=5000))
# 800 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=661, limit=5000))
# 801 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=658, limit=5000))
# 802 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=655, limit=5000))
# 803 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=652, limit=5000))
# 804 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=649, limit=5000))
# 805 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=646, limit=5000))
# 806 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=643, limit=5000))
# 807 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=640, limit=5000))
# 808 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=637, limit=5000))
# 809 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=634, limit=5000))
# 810 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=631, limit=5000))
# 811 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=628, limit=5000))
# 812 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=625, limit=5000))
# 813 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=622, limit=5000))
# 814 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=619, limit=5000))
# 815 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=616, limit=5000))
# 816 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=613, limit=5000))
# 817 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=610, limit=5000))
# 818 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=607, limit=5000))
# 819 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=604, limit=5000))
# 820 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=601, limit=5000))
# 821 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=598, limit=5000))
# 822 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=595, limit=5000))
# 823 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=592, limit=5000))
# 824 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=589, limit=5000))
# 825 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=586, limit=5000))
# 826 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=583, limit=5000))
# 827 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=580, limit=5000))
# 828 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=577, limit=5000))
# 829 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=574, limit=5000))
# 830 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=571, limit=5000))
# 831 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=568, limit=5000))
# 832 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=565, limit=5000))
# 833 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=562, limit=5000))
# 834 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=559, limit=5000))
# 835 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=556, limit=5000))
# 836 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=553, limit=5000))
# 837 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=550, limit=5000))
# 838 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=547, limit=5000))
# 839 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=544, limit=5000))
# 840 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=541, limit=5000))
# 841 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=538, limit=5000))
# 842 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=535, limit=5000))
# 843 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=532, limit=5000))
# 844 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=529, limit=5000))
# 845 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=526, limit=5000))
# 846 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=523, limit=5000))
# 847 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=520, limit=5000))
# 848 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=517, limit=5000))
# 849 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=514, limit=5000))
# 850 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=511, limit=5000))
# 851 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=508, limit=5000))
# 852 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=505, limit=5000))
# 853 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=502, limit=5000))
# 854 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=499, limit=5000))
# 855 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=496, limit=5000))
# 856 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=493, limit=5000))
# 857 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=490, limit=5000))
# 858 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=487, limit=5000))
# 859 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=484, limit=5000))
# 860 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=481, limit=5000))
# 861 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=478, limit=5000))
# 862 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=475, limit=5000))
# 863 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=472, limit=5000))
# 864 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=469, limit=5000))
# 865 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=466, limit=5000))
# 866 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=463, limit=5000))
# 867 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=460, limit=5000))
# 868 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=457, limit=5000))
# 869 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=454, limit=5000))
# 870 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=451, limit=5000))
# 871 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=448, limit=5000))
# 872 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=445, limit=5000))
# 873 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=442, limit=5000))
# 874 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=439, limit=5000))
# 875 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=436, limit=5000))
# 876 / 878
# RateLimit(core=Rate(reset=2022-07-30 23:45:00, remaining=433, limit=5000))
# 877 / 878

# %%
samples.to_csv("../1-ExtractDataPrs/Data2022/googleteste2022.csv", index=False)
